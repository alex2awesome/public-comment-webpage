# %% [markdown]
# # AI RFI call & comment reader
#
# This notebook inventories the call/outcome documents you asked to download and
# loads the normalized AI comment corpus that already lives in `data/app_data/ai_corpus.db`.
# Use it as a starting point for further analysis or summarization work.

# %%
from __future__ import annotations

from pathlib import Path
from zipfile import ZipFile

import pandas as pd
from bs4 import BeautifulSoup
from pdfminer.high_level import extract_text
from tqdm.auto import tqdm

from reader_utils import (
    resolve_project_root,
    get_project_paths,
    connect_export_db,
    read_text_blob,
)

PROJECT_ROOT = resolve_project_root()
PATHS = get_project_paths(PROJECT_ROOT)
EXPORT_DB_PATH = PATHS["export_db_path"]

print(f"Project root: {PROJECT_ROOT}")
print(f"Export DB   : {EXPORT_DB_PATH}")
# Out:
# Project root: /Users/spangher/Projects/stanford-research/rfi-research/regulations-demo
# Export DB   : /Users/spangher/Projects/stanford-research/rfi-research/regulations-demo/data/app_data/ai_corpus.db

# %% [markdown]
# ## Call / response documents
#
# Each row below records one of the call notices, reports, or combined response
# packages you listed. Paths stay relative to the repository root so collaborators
# on other machines can resolve them easily.

# %%
CALL_RESPONSE_DOCS = (
    pd.read_csv('ai_call_response_docs_list.csv', index_col=0)
    .assign(path=lambda df: df['path'].apply(Path))
    .to_dict(orient='records')
)

# %%
def build_call_response_index(records: list[dict]) -> pd.DataFrame:
    rows: list[dict] = []
    for record in records:
        rel_path = record["path"]
        abs_path = (PROJECT_ROOT / rel_path).resolve()
        exists = abs_path.exists()
        size_mb = abs_path.stat().st_size / 1_000_000 if exists else None
        rows.append({
            **{k: v for k, v in record.items() if k != "path"},
            "path": rel_path.as_posix(),
            "exists": exists,
            "size_mb": size_mb,
            "suffix": rel_path.suffix.lower(),
        })
    return pd.DataFrame(rows)

call_response_df = build_call_response_index(CALL_RESPONSE_DOCS)
call_response_df.sort_values(["jurisdiction", "collection_id", "document_role"]).reset_index(drop=True).head(3)
# Out:
#   jurisdiction collection_id    document_role                           title  \
# 0   California    PR-02-2023    call_overview  CPPA CCPA updates landing page
# 1   California    PR-02-2023     fsor_and_uid           CPPA FSOR & UID (PDF)
# 2   California    PR-02-2023  fsor_appendix_a      CPPA FSOR Appendix A (PDF)
#
#                                                  url  \
# 0  https://cppa.ca.gov/regulations/ccpa_updates.html
# 1  https://cppa.ca.gov/regulations/pdf/ccpa_updat...
# 2  https://cppa.ca.gov/regulations/pdf/ccpa_updat...
#
#                                                 path  exists   size_mb suffix
# 0  data/comments/cppa_admt/PR-02-2023/raw/ccpa_up...    True  0.050189  .html
# 1  data/comments/cppa_admt/PR-02-2023/raw/ccpa_up...    True  0.584846   .pdf
# 2  data/comments/cppa_admt/PR-02-2023/raw/ccpa_up...    True  5.017119   .pdf

# %%
def preview_document(row: pd.Series, max_chars: int = 800) -> str:
    path = PROJECT_ROOT / Path(row["path"])
    if not path.exists():
        return "<missing file>"
    suffix = path.suffix.lower()
    if suffix in {".html", ".htm"}:
        html = path.read_text(encoding="utf-8", errors="ignore")
        soup = BeautifulSoup(html, "html.parser")
        text = " ".join(s[: max_chars * 2 if max_chars is not None else max_chars] for s in soup.stripped_strings)
        return text[:max_chars]
    if suffix == ".zip":
        with ZipFile(path) as zf:
            members = sorted(zf.namelist())[:10]
        return "ZIP contains: " + ", ".join(members)
    if suffix == ".pdf":
        size_mb = path.stat().st_size / 1_000_000
        if size_mb > 5:
            return f"<PDF {size_mb:.1f} MB – load pages manually as needed>"
        try:
            text = extract_text(str(path), maxpages=2)
            return text[:max_chars]
        except Exception as exc:  # pragma: no cover
            return f"<pdf parse error: {exc}>"
    return path.read_text(encoding="utf-8", errors="ignore")[:max_chars]

call_response_df["preview"] = call_response_df.apply(preview_document, max_chars=None, axis=1)

# %%
call_response_df[["jurisdiction", "collection_id", "document_role", "title", "preview"]]
# Out:
#       jurisdiction                                      collection_id  \
# 0       US Federal                                     NTIA-2023-0005
# 1       US Federal                                     NTIA-2023-0005
# 2       US Federal                                     NTIA-2023-0009
# 3       US Federal                                      OMB-2023-0020
# 4       US Federal                                      OMB-2023-0020
# 5       US Federal                              AI-RMF-2ND-DRAFT-2022
# 6       US Federal                              AI-RMF-2ND-DRAFT-2022
# 7       US Federal                              AI-RMF-2ND-DRAFT-2022
# 8       US Federal                                         90-FR-9088
# 9       US Federal                                         90-FR-9088
# 10      US Federal                                         90-FR-9088
# 11      US Federal                                         90-FR-9088
# 12      US Federal                                         90-FR-9088
# 13      California                                         PR-02-2023
# 14      California                                         PR-02-2023
# 15      California                                         PR-02-2023
# 16      California                                         PR-02-2023
# 17  European Union                                 WHITEPAPER-AI-2020
# 18  European Union                                 WHITEPAPER-AI-2020
# 19  European Union                                 WHITEPAPER-AI-2020
# 20  European Union                      AI-ACT-2021-ADOPTION-FEEDBACK
# 21  European Union                      AI-ACT-2021-ADOPTION-FEEDBACK
# 22  European Union                      AI-ACT-2021-ADOPTION-FEEDBACK
# 23  European Union                      AI-ACT-2021-ADOPTION-FEEDBACK
# 24  United Kingdom                                ai-white-paper-2023
# 25  United Kingdom                                ai-white-paper-2023
# 26  United Kingdom                                ai-white-paper-2023
# 27  United Kingdom  government_consultations_ai-regulation-a-pro-i...
# 28  United Kingdom  government_consultations_ai-regulation-a-pro-i...
# 29  United Kingdom  government_consultations_ai-regulation-a-pro-i...
# 30  United Kingdom  government_consultations_ai-regulation-a-pro-i...
# 31  United Kingdom  government_consultations_copyright-and-artific...
# 32  United Kingdom  government_consultations_copyright-and-artific...
# 33  United Kingdom  government_consultations_copyright-and-artific...
#
#                document_role  \
# 0              call_overview
# 1             summary_report
# 2             summary_report
# 3            policy_guidance
# 4        supporting_material
# 5              call_overview
# 6           response_summary
# 7            final_framework
# 8                call_notice
# 9              responses_pdf
# 10             responses_zip
# 11               action_plan
# 12           action_plan_web
# 13             call_overview
# 14              fsor_and_uid
# 15           fsor_appendix_a
# 16           fsor_appendix_b
# 17             call_overview
# 18                  call_pdf
# 19          response_summary
# 20             call_overview
# 21  impact_assessment_part_1
# 22  impact_assessment_part_2
# 23    impact_assessment_doc2
# 24             call_overview
# 25          white_paper_html
# 26           white_paper_pdf
# 27             call_overview
# 28         response_overview
# 29          response_pdf_web
# 30        response_pdf_print
# 31             call_overview
# 32               call_detail
# 33         response_overview
#
#                                                 title  \
# 0   NTIA – AI Accountability policy report landing...
# 1         NTIA – AI Accountability final report (PDF)
# 2           NTIA – Dual use / open model report (PDF)
# 3                              OMB M-24-10 memo (PDF)
# 4                       OMB docket attachment 2 (PDF)
# 5               NIST AI Risk Management Framework hub
# 6                  NIST AI RMF response summary (PDF)
# 7                                 NIST AI 100-1 (PDF)
# 8        Federal Register notice – AI Action Plan RFI
# 9               NITRD combined responses bundle (PDF)
# 10              NITRD combined responses bundle (ZIP)
# 11                     America's AI Action Plan (PDF)
# 12                    AI.gov action plan landing page
# 13                     CPPA CCPA updates landing page
# 14                              CPPA FSOR & UID (PDF)
# 15                         CPPA FSOR Appendix A (PDF)
# 16                         CPPA FSOR Appendix B (PDF)
# 17                        EC White Paper landing page
# 18                                 EC White Paper PDF
# 19             White Paper consultation summary (PDF)
# 20                     AI Act proposal (EUR-Lex HTML)
# 21            AI Act impact assessment – part 1 (PDF)
# 22            AI Act impact assessment – part 2 (PDF)
# 23             AI Act impact assessment – DOC_2 (PDF)
# 24                 UK DSIT AI regulation landing page
# 25                  UK AI regulation white paper HTML
# 26           Statewatch copy of the white paper (PDF)
# 27  Consultation page for AI regulation policy pro...
# 28                   Government response landing page
# 29                Government response (web-ready PDF)
# 30              Government response (print-ready PDF)
# 31           UK IPO AI & IP consultation landing page
# 32                    UK IPO consultation detail page
# 33                   UK IPO consultation outcome page
#
#                                               preview
# 0   AI Accountability Policy Report | National Tel...
# 1   NTIA \n\nArtificial Intelligence \nAccountabil...
# 2    Dual-Use Foundation \n Models with Widely \n ...
# 3   EXECUTIVE OFFICE OF THE  PRESIDENT  \nO F F I ...
# 4     Guidance on Advancing Governance, Innovation...
# 5   AI Risk Management Framework | NIST Skip to ma...
# 6   Summary Analysis of Responses to the NIST Arti...
# 7   NIST AI 100-1\n\nArtificial Intelligence Risk ...
# 8   Federal Register :: Request Access Request Acc...
# 9      <PDF 658.8 MB – load pages manually as needed>
# 10  ZIP contains: 90-fr-9088-combined-responses/, ...
# 11  T H E   W H I T E   H O U S E  \n\nWinning the...
# 12  AI Action Plan AI GOV president donald j. trum...
# 13  CCPA Updates, Cybersecurity Audits, Risk Asses...
# 14  CALIFORNIA PRIVACY PROTECTION AGENCY  \n\nTITL...
# 15       <PDF 5.0 MB – load pages manually as needed>
# 16  FSOR APPENDIX B – SUMMARIES AND RESPONSES TO 1...
# 17  White Paper on Artificial Intelligence: a Euro...
# 18  EN \n\n  EN \n\n   EUROPEAN COMMISSION  Brusse...
# 19   P \n\nPublic consultation on the AI White Pap...
# 20  EUR-Lex - 52021PC0206 - EN - EUR-Lex × Skip to...
# 21  EN \n\n  EN \n\n   EUROPEAN COMMISSION  Brusse...
# 22  EN \n\n  EN \n\n   EUROPEAN COMMISSION  Brusse...
# 23  EN \n\n  EN \n\n   EUROPEAN COMMISSION  Brusse...
# 24  AI regulation: a pro-innovation approach - GOV...
# 25  A pro-innovation approach to AI regulation - G...
# 26  A pro-innovation approach \nto AI regulation \...
# 27  AI regulation: a pro-innovation approach – pol...
# 28  A pro-innovation approach to AI regulation: go...
# 29  A pro-innovation approach \nto AI regulation\n...
# 30  A pro-innovation approach \nto AI regulation\n...
# 31  Artificial Intelligence and IP: copyright and ...
# 32  Artificial Intelligence and Intellectual Prope...
# 33  Artificial Intelligence and Intellectual Prope...

# %%
import prompt_utils as p

# %%
IDENTIFICATION_PROMPT = """You are a helpful legal assistant. 
Please tell me if this text CONTAINS government responses to comments submitted. Do NOT identify texts 
that simply mention comment-gathering process. The text must specifically AND directly respond directly to user comments.
Answer with just "yes" or "no":

<text>
{input_text}
</text>

Your response:
"""

# %%
all_responses = await p.process_batch(
    call_response_df['preview'], 
    prompt_template=IDENTIFICATION_PROMPT, 
    model='gpt-5-mini', 
    concurrency=50
)
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]

# %%
! open ../data/comments/nitrd_ai_rfi/90-FR-9088/raw/90-fr-9088-combined-responses.pdf

# %%
call_response_df.sort_values('size_mb', ascending=False)
# Out:
#       jurisdiction                                      collection_id  \
# 9       US Federal                                         90-FR-9088
# 10      US Federal                                         90-FR-9088
# 15      California                                         PR-02-2023
# 1       US Federal                                     NTIA-2023-0005
# 21  European Union                      AI-ACT-2021-ADOPTION-FEEDBACK
# 30  United Kingdom  government_consultations_ai-regulation-a-pro-i...
# 7       US Federal                              AI-RMF-2ND-DRAFT-2022
# 2       US Federal                                     NTIA-2023-0009
# 29  United Kingdom  government_consultations_ai-regulation-a-pro-i...
# 16      California                                         PR-02-2023
# 19  European Union                                 WHITEPAPER-AI-2020
# 23  European Union                      AI-ACT-2021-ADOPTION-FEEDBACK
# 26  United Kingdom                                ai-white-paper-2023
# 28  United Kingdom  government_consultations_ai-regulation-a-pro-i...
# 18  European Union                                 WHITEPAPER-AI-2020
# 25  United Kingdom                                ai-white-paper-2023
# 22  European Union                      AI-ACT-2021-ADOPTION-FEEDBACK
# 20  European Union                      AI-ACT-2021-ADOPTION-FEEDBACK
# 14      California                                         PR-02-2023
# 3       US Federal                                      OMB-2023-0020
# 11      US Federal                                         90-FR-9088
# 6       US Federal                              AI-RMF-2ND-DRAFT-2022
# 4       US Federal                                      OMB-2023-0020
# 32  United Kingdom  government_consultations_copyright-and-artific...
# 17  European Union                                 WHITEPAPER-AI-2020
# 33  United Kingdom  government_consultations_copyright-and-artific...
# 0       US Federal                                     NTIA-2023-0005
# 31  United Kingdom  government_consultations_copyright-and-artific...
# 27  United Kingdom  government_consultations_ai-regulation-a-pro-i...
# 5       US Federal                              AI-RMF-2ND-DRAFT-2022
# 24  United Kingdom                                ai-white-paper-2023
# 12      US Federal                                         90-FR-9088
# 13      California                                         PR-02-2023
# 8       US Federal                                         90-FR-9088
#
#                document_role  \
# 9              responses_pdf
# 10             responses_zip
# 15           fsor_appendix_a
# 1             summary_report
# 21  impact_assessment_part_1
# 30        response_pdf_print
# 7            final_framework
# 2             summary_report
# 29          response_pdf_web
# 16           fsor_appendix_b
# 19          response_summary
# 23    impact_assessment_doc2
# 26           white_paper_pdf
# 28         response_overview
# 18                  call_pdf
# 25          white_paper_html
# 22  impact_assessment_part_2
# 20             call_overview
# 14              fsor_and_uid
# 3            policy_guidance
# 11               action_plan
# 6           response_summary
# 4        supporting_material
# 32               call_detail
# 17             call_overview
# 33         response_overview
# 0              call_overview
# 31             call_overview
# 27             call_overview
# 5              call_overview
# 24             call_overview
# 12           action_plan_web
# 13             call_overview
# 8                call_notice
#
#                                                 title  \
# 9               NITRD combined responses bundle (PDF)
# 10              NITRD combined responses bundle (ZIP)
# 15                         CPPA FSOR Appendix A (PDF)
# 1         NTIA – AI Accountability final report (PDF)
# 21            AI Act impact assessment – part 1 (PDF)
# 30              Government response (print-ready PDF)
# 7                                 NIST AI 100-1 (PDF)
# 2           NTIA – Dual use / open model report (PDF)
# 29                Government response (web-ready PDF)
# 16                         CPPA FSOR Appendix B (PDF)
# 19             White Paper consultation summary (PDF)
# 23             AI Act impact assessment – DOC_2 (PDF)
# 26           Statewatch copy of the white paper (PDF)
# 28                   Government response landing page
# 18                                 EC White Paper PDF
# 25                  UK AI regulation white paper HTML
# 22            AI Act impact assessment – part 2 (PDF)
# 20                     AI Act proposal (EUR-Lex HTML)
# 14                              CPPA FSOR & UID (PDF)
# 3                              OMB M-24-10 memo (PDF)
# 11                     America's AI Action Plan (PDF)
# 6                  NIST AI RMF response summary (PDF)
# 4                       OMB docket attachment 2 (PDF)
# 32                    UK IPO consultation detail page
# 17                        EC White Paper landing page
# 33                   UK IPO consultation outcome page
# 0   NTIA – AI Accountability policy report landing...
# 31           UK IPO AI & IP consultation landing page
# 27  Consultation page for AI regulation policy pro...
# 5               NIST AI Risk Management Framework hub
# 24                 UK DSIT AI regulation landing page
# 12                    AI.gov action plan landing page
# 13                     CPPA CCPA updates landing page
# 8        Federal Register notice – AI Action Plan RFI
#
#                                                   url  \
# 9   https://files.nitrd.gov/90-fr-9088/90-fr-9088-...
# 10  https://files.nitrd.gov/90-fr-9088/90-fr-9088-...
# 15  https://cppa.ca.gov/regulations/pdf/ccpa_updat...
# 1   https://www.ntia.gov/sites/default/files/publi...
# 21  https://artificialintelligenceact.eu/wp-conten...
# 30  https://assets.publishing.service.gov.uk/media...
# 7   https://nvlpubs.nist.gov/nistpubs/ai/NIST.AI.1...
# 2   https://www.ntia.gov/sites/default/files/publi...
# 29  https://assets.publishing.service.gov.uk/media...
# 16  https://www.cppa.ca.gov/regulations/pdf/ccpa_u...
# 19  https://ec.europa.eu/newsroom/dae/document.cfm...
# 23  https://eur-lex.europa.eu/resource.html?format...
# 26  https://www.statewatch.org/media/3924/uk-ai-wh...
# 28  https://www.gov.uk/government/consultations/ai...
# 18  https://commission.europa.eu/system/files/2020...
# 25  https://www.gov.uk/government/publications/ai-...
# 22  https://artificialintelligenceact.eu/wp-conten...
# 20  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 14  https://cppa.ca.gov/regulations/pdf/ccpa_updat...
# 3   https://www.whitehouse.gov/wp-content/uploads/...
# 11  https://www.whitehouse.gov/wp-content/uploads/...
# 6   https://www.nist.gov/document/summary-analysis...
# 4   https://downloads.regulations.gov/OMB-2023-002...
# 32  https://www.gov.uk/government/consultations/ar...
# 17  https://commission.europa.eu/publications/whit...
# 33  https://www.gov.uk/government/consultations/ar...
# 0   https://www.ntia.gov/issues/artificial-intelli...
# 31  https://www.gov.uk/government/consultations/ar...
# 27  https://www.gov.uk/government/consultations/ai...
# 5   https://www.nist.gov/itl/ai-risk-management-fr...
# 24  https://www.gov.uk/government/publications/ai-...
# 12                     https://www.ai.gov/action-plan
# 13  https://cppa.ca.gov/regulations/ccpa_updates.html
# 8   https://www.federalregister.gov/documents/2025...
#
#                                                  path  exists     size_mb  \
# 9   data/comments/nitrd_ai_rfi/90-FR-9088/raw/90-f...    True  658.839315
# 10  data/comments/nitrd_ai_rfi/90-FR-9088/raw/90-f...    True  616.016643
# 15  data/comments/cppa_admt/PR-02-2023/raw/ccpa_up...    True    5.017119
# 1   data/comments/regulations_gov/NTIA-2023-0005/r...    True    3.047281
# 21  data/comments/eu_have_your_say_playwright/AI-A...    True    2.614941
# 30  data/comments/gov_uk/government_consultations_...    True    2.402245
# 7   data/comments/nist_airmf/AI-RMF-2ND-DRAFT-2022...    True    1.946127
# 2   data/comments/regulations_gov/NTIA-2023-0009/r...    True    1.822164
# 29  data/comments/gov_uk/government_consultations_...    True    1.745743
# 16  data/comments/cppa_admt/PR-02-2023/raw/ccpa_up...    True    1.590247
# 19  data/comments/eu_have_your_say_playwright/WHIT...    True    1.447823
# 23  data/comments/eu_have_your_say_playwright/AI-A...    True    1.440595
# 26  data/comments/gov_uk/ai-white-paper-2023/raw/u...    True    1.227118
# 28  data/comments/gov_uk/government_consultations_...    True    1.024838
# 18  data/comments/eu_have_your_say_playwright/WHIT...    True    0.961904
# 25  data/comments/gov_uk/ai-white-paper-2023/raw/a...    True    0.839316
# 22  data/comments/eu_have_your_say_playwright/AI-A...    True    0.832284
# 20  data/comments/eu_have_your_say_playwright/AI-A...    True    0.799833
# 14  data/comments/cppa_admt/PR-02-2023/raw/ccpa_up...    True    0.584846
# 3   data/comments/regulations_gov/OMB-2023-0020/ra...    True    0.530549
# 11  data/comments/nitrd_ai_rfi/90-FR-9088/raw/Amer...    True    0.521617
# 6   data/comments/nist_airmf/AI-RMF-2ND-DRAFT-2022...    True    0.273653
# 4   data/comments/regulations_gov/OMB-2023-0020/ra...    True    0.197809
# 32  data/comments/gov_uk/government_consultations_...    True    0.194876
# 17  data/comments/eu_have_your_say_playwright/WHIT...    True    0.171087
# 33  data/comments/gov_uk/government_consultations_...    True    0.165542
# 0   data/comments/regulations_gov/NTIA-2023-0005/r...    True    0.099764
# 31  data/comments/gov_uk/government_consultations_...    True    0.094098
# 27  data/comments/gov_uk/government_consultations_...    True    0.092497
# 5   data/comments/nist_airmf/AI-RMF-2ND-DRAFT-2022...    True    0.089946
# 24  data/comments/gov_uk/ai-white-paper-2023/raw/a...    True    0.088283
# 12  data/comments/nitrd_ai_rfi/90-FR-9088/raw/ai-g...    True    0.058438
# 13  data/comments/cppa_admt/PR-02-2023/raw/ccpa_up...    True    0.050189
# 8   data/comments/nitrd_ai_rfi/90-FR-9088/raw/requ...    True    0.004273
#
#    suffix                                            preview contains_response
# 9    .pdf     <PDF 658.8 MB – load pages manually as needed>                no
# 10   .zip  ZIP contains: 90-fr-9088-combined-responses/, ...                no
# 15   .pdf       <PDF 5.0 MB – load pages manually as needed>                no
# 1    .pdf  NTIA \n\nArtificial Intelligence \nAccountabil...                no
# 21   .pdf  EN \n\n  EN \n\n   EUROPEAN COMMISSION  Brusse...                no
# 30   .pdf  A pro-innovation approach \nto AI regulation\n...                no
# 7    .pdf  NIST AI 100-1\n\nArtificial Intelligence Risk ...                no
# 2    .pdf   Dual-Use Foundation \n Models with Widely \n ...                no
# 29   .pdf  A pro-innovation approach \nto AI regulation\n...                no
# 16   .pdf  FSOR APPENDIX B – SUMMARIES AND RESPONSES TO 1...               yes
# 19   .pdf   P \n\nPublic consultation on the AI White Pap...                no
# 23   .pdf  EN \n\n  EN \n\n   EUROPEAN COMMISSION  Brusse...                no
# 26   .pdf  A pro-innovation approach \nto AI regulation \...                no
# 28  .html  A pro-innovation approach to AI regulation: go...               yes
# 18   .pdf  EN \n\n  EN \n\n   EUROPEAN COMMISSION  Brusse...                no
# 25  .html  A pro-innovation approach to AI regulation - G...               yes
# 22   .pdf  EN \n\n  EN \n\n   EUROPEAN COMMISSION  Brusse...                no
# 20  .html  EUR-Lex - 52021PC0206 - EN - EUR-Lex × Skip to...                no
# 14   .pdf  CALIFORNIA PRIVACY PROTECTION AGENCY  \n\nTITL...                no
# 3    .pdf  EXECUTIVE OFFICE OF THE  PRESIDENT  \nO F F I ...                no
# 11   .pdf  T H E   W H I T E   H O U S E  \n\nWinning the...                no
# 6    .pdf  Summary Analysis of Responses to the NIST Arti...                no
# 4    .pdf    Guidance on Advancing Governance, Innovation...               yes
# 32  .html  Artificial Intelligence and Intellectual Prope...               yes
# 17  .html  White Paper on Artificial Intelligence: a Euro...                no
# 33  .html  Artificial Intelligence and Intellectual Prope...               yes
# 0   .html  AI Accountability Policy Report | National Tel...                no
# 31  .html  Artificial Intelligence and IP: copyright and ...               yes
# 27  .html  AI regulation: a pro-innovation approach – pol...                no
# 5   .html  AI Risk Management Framework | NIST Skip to ma...                no
# 24  .html  AI regulation: a pro-innovation approach - GOV...                no
# 12  .html  AI Action Plan AI GOV president donald j. trum...                no
# 13  .html  CCPA Updates, Cybersecurity Audits, Risk Asses...                no
# 8   .html  Federal Register :: Request Access Request Acc...                no

# %%
call_response_df['contains_response'] = all_responses

# %%
PULL_CHUNKS_PROMPT = """You are a helpful legal assistant. I will show you a government document.
It contains responses to comments submitted by members of the public.
Please extract ALL the text that directly responds to submitted comments.
Do NOT identify text that simply mentions the comment-gathering process. 
The text must specifically AND directly respond directly to comments.

Respond in the following format:

[
{{'content_of_comment': <any mention the report makes to identify a specific comment>,
'response_to_comment': <any reponse made by the agency>,
}},
]

Include on list item per specific comment (or group of comments) if possible. 
Respond only with text extracted from the file, no other information. 

<file>
{input_text}
</file>

Your response:
"""

# %%
call_response_df.loc[lambda df: df['contains_response'] == 'yes']['preview'].str.split().str.len()
# Out:
# 4       927
# 16      998
# 25    32223
# 28    44284
# 31     1422
# 32     7779
# 33     6092
# Name: preview, dtype: int64

# %%
import json
import ast
import prompt_utils

# %%
comment_responses = call_response_df.loc[lambda df: df['contains_response'] == 'yes']

# %%
output_3 = await prompt_utils.process_batch(
    comment_responses['preview'], 
    prompt_template=PULL_CHUNKS_PROMPT,
    model='gpt-5',
    max_attempts=5
)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
full_output = []
for output_iter in [output, output_2, output_3]:
    for idx, o in enumerate(output_iter):
        try:
            p = json.loads(o)
        except:
            p = ast.literal_eval(o)
        if not isinstance(p, list):
            p = [p]
        full_output.append({
            'doc_id': idx, 'output': p
        })

# %%
full_output_df = pd.DataFrame(full_output)
full_output_df.to_json('ai_extracted_comment_cache.jsonl', lines=True, orient='records')

# %%
from more_itertools import flatten

agg_responses = (
    full_output_df
     .loc[lambda df: ~df.apply(lambda x: 'error' in x['output'][0], axis=1)]
     .groupby('doc_id')['output']
     .aggregate(list).apply(lambda x: list(flatten(x)))
     .to_frame('responses_to_comments')
)

# %% [markdown]
# ## Comment corpus loader
#
# The cells below pull every normalized document for the AI RFIs/RFCs already in
# `ai_corpus.db`. Update `TARGET_COLLECTIONS` if you add more dockets later.

# %%
TARGET_COLLECTIONS = [
    {"source": "regulations_gov", "collection_id": "NTIA-2023-0005", "label": "NTIA – AI Accountability RFC"},
    {"source": "regulations_gov", "collection_id": "NTIA-2023-0009", "label": "NTIA – Dual Use/Open Model RFC"},
    {"source": "regulations_gov", "collection_id": "OMB-2023-0020", "label": "OMB – M-24-10 draft guidance"},
    {"source": "nist_airmf", "collection_id": "AI-RMF-2ND-DRAFT-2022", "label": "NIST – AI RMF second draft"},
    {"source": "nitrd_ai_rfi", "collection_id": "90-FR-9088", "label": "OSTP/NITRD – AI Action Plan RFI"},
    {"source": "cppa_admt", "collection_id": "PR-02-2023", "label": "CPPA – PR 02-2023"},
    {"source": "eu_have_your_say_playwright", "collection_id": "WHITEPAPER-AI-2020", "label": "EU – AI White Paper"},
    {"source": "eu_have_your_say_playwright", "collection_id": "AI-ACT-2021-ADOPTION-FEEDBACK", "label": "EU – AI Act feedback"},
    {"source": "gov_uk", "collection_id": "ai-white-paper-2023", "label": "UK – AI regulation white paper"},
    {"source": "gov_uk", "collection_id": "government_consultations_ai-regulation-a-pro-innovation-approach-policy-proposals", "label": "UK – AI regulation consultation"},
    {"source": "gov_uk", "collection_id": "government_consultations_copyright-and-artificial-intelligence", "label": "UK IPO – AI & IP consultation"},
]

collection_lookup = pd.DataFrame(TARGET_COLLECTIONS)
collection_ids = collection_lookup["collection_id"].tolist()
placeholders = ", ".join(["?"] * len(collection_ids))

with connect_export_db(EXPORT_DB_PATH) as conn:
    summary_sql = f"""
        SELECT source, collection_id, COUNT(*) AS documents,
               SUM(CASE WHEN text_path IS NOT NULL THEN 1 ELSE 0 END) AS docs_with_text,
               MIN(submitted_at) AS first_submitted_at,
               MAX(submitted_at) AS last_submitted_at
        FROM documents
        WHERE collection_id IN ({placeholders})
        GROUP BY source, collection_id
        ORDER BY source, collection_id
    """
    summary_df = pd.read_sql(summary_sql, conn, params=collection_ids)

summary_df.merge(collection_lookup, on=["source", "collection_id"]).loc[:, [
    "source", "collection_id", "label", "documents", "docs_with_text", "first_submitted_at", "last_submitted_at"
]]
# Out:
#             source          collection_id                            label  \
# 0        cppa_admt             PR-02-2023                CPPA – PR 02-2023
# 1       nist_airmf  AI-RMF-2ND-DRAFT-2022       NIST – AI RMF second draft
# 2     nitrd_ai_rfi             90-FR-9088  OSTP/NITRD – AI Action Plan RFI
# 3  regulations_gov         NTIA-2023-0005     NTIA – AI Accountability RFC
# 4  regulations_gov         NTIA-2023-0009   NTIA – Dual Use/Open Model RFC
# 5  regulations_gov          OMB-2023-0020     OMB – M-24-10 draft guidance
#
#    documents  docs_with_text    first_submitted_at     last_submitted_at
# 0        592             592         April 1, 2028      November 8, 2024
# 1         85              85                  None                  None
# 2          2               2            2025-02-06            2025-02-06
# 3       1452            1452  2023-04-13T04:00:00Z  2023-06-27T04:00:00Z
# 4        335             335  2024-02-26T05:00:00Z  2024-06-20T04:00:00Z
# 5        197             197  2023-11-03T04:00:00Z  2023-12-07T05:00:00Z

# %%
with connect_export_db(EXPORT_DB_PATH) as conn:
    detail_sql = f"""
        SELECT doc_id, source, collection_id, title, submitter_name, submitted_at, text_path
        FROM documents
        WHERE collection_id IN ({placeholders})
        ORDER BY collection_id, submitted_at
    """
    comments_df = pd.read_sql(detail_sql, conn, params=collection_ids)

print(f"Loaded {len(comments_df):,} normalized documents")
# Out:
# Loaded 2,663 normalized documents

# %%
def hydrate_text_blobs(text_paths: pd.Series) -> list[str | None]:
    hydrated: list[str | None] = []
    for raw in tqdm(text_paths, desc="Loading text blobs"):
        if isinstance(raw, str) and raw.strip():
            hydrated.append(read_text_blob(PROJECT_ROOT, raw))
        else:
            hydrated.append(None)
    return hydrated

comments_df["text"] = hydrate_text_blobs(comments_df["text_path"])
comments_df.head()
# Out:
# Loading text blobs:   0%|          | 0/2663 [00:00<?, ?it/s]
#                   doc_id        source          collection_id  \
# 0  CAIDP-AI-RFI-2025.pdf  nitrd_ai_rfi             90-FR-9088
# 1             2025-02305  nitrd_ai_rfi             90-FR-9088
# 2   AI_RMF_2nd_draft.pdf    nist_airmf  AI-RMF-2ND-DRAFT-2022
# 3          Accenture.pdf    nist_airmf  AI-RMF-2ND-DRAFT-2022
# 4   Adelin_20Travers.pdf    nist_airmf  AI-RMF-2ND-DRAFT-2022
#
#                                                title  \
# 0                              CAIDP-AI-RFI-2025.pdf
# 1  Request for Information on the Development of ...
# 2   second draft of the AI Risk Management Framework
# 3                                          Accenture
# 4                                     Adelin Travers
#
#                                      submitter_name submitted_at  \
# 0                                              None         None
# 1                                      OSTP & NITRD   2025-02-06
# 2  second draft of the AI Risk Management Framework         None
# 3                                         Accenture         None
# 4                                    Adelin Travers         None
#
#                                            text_path  \
# 0  data/comments/blobs/a6/a61897bca3e8eb6ba6d4cb1...
# 1  data/comments/blobs/9b/9b6e5baccf22f4e40bfa5eb...
# 2  data/comments/blobs/0b/0b134d057ab06d3a3a014e9...
# 3  data/comments/blobs/43/4370afc6e8a6099d565f382...
# 4  data/comments/blobs/35/350725d68762a101c3a74ae...
#
#                                                 text
# 0  Comments to the \n\nUnited States Office of Sc...
# 1  9088 \n\nFederal  Register / Vol.  90,  No.  2...
# 2  AI Risk Management Framework: Second Draft \n\...
# 3  August 29, 2022 \n\nDr. Laurie E. Locascio   \...
# 4  1/19 \n\nComments  on  the  2nd  draft  of  th...

# %%
comment_summary = (
    comments_df
    .assign(has_text=comments_df["text"].notna())
    .groupby(["source", "collection_id"], as_index=False)
    .agg(documents=("doc_id", "count"), docs_with_text=("has_text", "sum"))
    .merge(collection_lookup, on=["source", "collection_id"])
)

comment_summary[["source", "collection_id", "label", "documents", "docs_with_text"]]
# Out:
#             source          collection_id                            label  \
# 0        cppa_admt             PR-02-2023                CPPA – PR 02-2023
# 1       nist_airmf  AI-RMF-2ND-DRAFT-2022       NIST – AI RMF second draft
# 2     nitrd_ai_rfi             90-FR-9088  OSTP/NITRD – AI Action Plan RFI
# 3  regulations_gov         NTIA-2023-0005     NTIA – AI Accountability RFC
# 4  regulations_gov         NTIA-2023-0009   NTIA – Dual Use/Open Model RFC
# 5  regulations_gov          OMB-2023-0020     OMB – M-24-10 draft guidance
#
#    documents  docs_with_text
# 0        592             592
# 1         85              85
# 2          2               2
# 3       1452            1452
# 4        335             335
# 5        197             197

# %%
sample_comments = (
    comments_df
    .dropna(subset=["text"])
    .groupby("collection_id")
    .head(1)
    .loc[:, ["collection_id", "doc_id", "submitter_name", "title", "text"]]
    .assign(text_preview=lambda df: df["text"].str.slice(0, 800))
)

sample_comments[["collection_id", "doc_id", "submitter_name", "text_preview"]]
# Out:
#               collection_id                 doc_id  \
# 0                90-FR-9088  CAIDP-AI-RFI-2025.pdf
# 2     AI-RMF-2ND-DRAFT-2022   AI_RMF_2nd_draft.pdf
# 87           NTIA-2023-0005          FR-2023-07776
# 1539         NTIA-2023-0009          FR-2024-03763
# 1874          OMB-2023-0020          FR-2023-24269
# 2071             PR-02-2023           web_cert.pdf
#
#                                         submitter_name  \
# 0                                                 None
# 2     second draft of the AI Risk Management Framework
# 87                                                NTIA
# 1539                                              NTIA
# 1874                                               OMB
# 2071                                              None
#
#                                            text_preview
# 0     Comments to the \n\nUnited States Office of Sc...
# 2     AI Risk Management Framework: Second Draft \n\...
# 87    Federal  Register / Vol.  88,  No.  71 / Thurs...
# 1539  Federal  Register / Vol.  89,  No.  38 / Monda...
# 1874  Federal  Register / Vol.  88,  No.  212 / Frid...
# 2071  Website Accessibility Certification \n\nCalifo...

# %% [markdown]
# # Match comments to references to them

# %%
print(comments_df
 .loc[lambda df: df['collection_id'].isin(comment_responses['collection_id'])]
 ['text'].iloc[5]
)
# Out:
# Shalanda Young
# Director Office of Management and Budget
# 72517th St NW, Washington, DC 20503
#
# November 4, 2023
#
# Re:  AI  Memo  Request  for  Comment:  Comments  of  Merve  Hickok  to  the  Office  of
# Management and Budget (OMB) regarding the Draft Memorandum published in Federal
# Register 88 FR 75625
#
# Dear Director Young,
#
# The below is in response to the request for public comments on the draft memorandum
# titled  Advancing  Governance,  Innovation,  and  Risk  Management  for  Agency  Use  of  Artificial
# Intelligence (AI)1.
#
# As the Founder of AIethicist.org, President  and Research Director at  Center for AI  and
# Digital  Policy  (CAIDP),  and  Data  Ethics  Lecturer  at  University  of  Michigan,  School  of
# Information.  I  welcome  the  opportunity  to  comment  on  The  Notice  seeks  comments  on  the
# Proposed Memorandum for the Heads of Executive Departments and Agencies  (hereinafter the
# “Guidance”).2 My work is focused on AI policy and governance globally. In my role at CAIDP,
# I testified in the United States Congress.3 I also continue to provide expert input to the Council of
# Europe AI convention, and EU AI Act.4
#
# I conduct research, and provide training, and consulting on how to develop, procure, use
# and  govern  trustworthy  AI.  In  2022,  I  published  “Public  procurement  of  artificial  intelligence
# systems:  new  risks  and  future  proofing.”5  I  am  currently  writing  a  book  on  implementation  of
# trustworthy AI in public procurement decisions. For this project, I conducted 20+ interviews with
# procurement  practitioners  across  the  agencies  in  the  United  States,  United  Kingdom,  Canada,
# Belgium, and Chile. I am also one of the co-authors of CAIDP’s annual report “AI and Democratic
# Values Index,”6 where we conduct comparative and longitudinal analysis of national AI policies
# and government use of AI systems. My comments reflect my years of research and analysis on
# government use of AI. This document answers questions 2, 3, 5, 6, 7 and 8 in the RFI.
#
# 1 Office of Management and Budget, Request for Comments on Advancing Governance, Innovation, and Risk
# Management for Agency Use of Artificial Intelligence Draft Memorandum, 88 FR 75625, No. 2023-24269, (Nov.
# 03, 2023), https://www.govinfo.gov/content/pkg/FR-2023-11-03/pdf/2023-24269.pdf
# 2 Ibid.
# 3 Testimony and statement for the record of CAIDP President Merve Hickok, Advances in AI: Are We
# Ready For a Tech Revolution?, House Committee on Oversight and Accountability: Subcommittee on
# Cybersecurity, information Technology, and Government Innovation (Mar. 8, 2023),
# https://oversight.house.gov/wp-content/uploads/2023/03/Merve-Hickok_testimony_March-8th-2023.pdf.
# 4 CAIDP, https://www.caidp.org.
# 5 Hickok, M. Public procurement of artificial intelligence systems: new risks and future proofing. AI & Soc (2022).
# https://doi.org/10.1007/s00146-022-01572-2
# 6 CAIDP, AI and Democratic Values (2023), https://www.caidp.org/reports/aidv-2022/
#
# Written Comments from Merve Hickok
# In response to Draft Memorandum published in Federal Register 88 FR 75625
#
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I  commend  the  OMB  for  providing  draft  guidance  to  implement  the  Executive  Order
# 14110, based on the principles of democratic values, human rights,  and the rule of law, and to
# ensure trustworthy use of AI by federal agencies.7 In particular, I applaud
#
# •  Promotion and incorporation of the Blueprint for an AI Bill of Rights8 and NIST AI Risk
#
# Management Framework9;
#
# •  Establishment  of  ‘minimum  practices’  for  government  agencies  to  follow  in  design,
#
# development, and use of AI systems;
#
# •  The  requirement  for  the  agencies  to  document  the  intended  purpose  for  the  AI  and  its
# expected benefit, supported by specific metrics or qualitative analysis. Such transparency
# would  provide  evidence  that  the  government  has  conducted  necessary  evaluations  to
# establish AI is indeed necessary for the purpose, and has verified that the system is capable
# of meeting the quantitative and qualitative expectations.
#
# •  The termination obligation requiring agencies to ensure AI systems have guardrails before
# they are put to use, and those already in existence but cannot be brought into compliance
# must be terminated.
#
# •  The  mandate  for  agencies  to  document  the  provenance  and  quality  of  the  data  for  its
#
# intended purpose.
#
# 5. Are there use cases for presumed safety-impacting and rights-impacting AI (Section 5 (b)) that
# should be included, removed, or revised? If so, why?
#
# Yes, the following are listed as rights-impacting AI, and the Guidance leaves it to each agency to
# determine whether the system can be used within a specific-context and use case. However, the
# list contains AI systems which are pseudoscientific, and undermine rule of law, presumption
# of innocence and human dignity. The list should be revised to include bans for these systems.
#
# •  Ban emotion analysis  systems: which claim to infer emotions from physical features and
# micro gestures. In-depth research shows there is no universal manifestation of an emotion,
# and the way individuals express emotions are dependent on the context, consequences  and
# cultural  upbringing.10  Such  systems  can  also  discriminate  against  people  with  facial
# disorders and disfigurement.
#
# •  Ban  thought,  emotion,  and  deception  detection  systems:  Not  only  are  these  systems
# without a scientific basis, but they can be weaponized for a variety of reasons under the
# veneer of ‘objective’ technologies.
#
# 7 Executive Order 14110, Safe, Secure, and Trustworthy Development and Use of Artificial Intelligence, 88 FR
# 75191, (Oct. 30, 2023), https://www.govinfo.gov/content/pkg/FR-2023-11-01/pdf/2023-24283.pdf
# 8 Blueprint for an AI Bill of Rights, White House Office of Science and Technology Policy,
# https://www.whitehouse.gov/wp-content/uploads/2022/10/Blueprint-for-an-AI-Bill-of-Rights.pdf.
# 9 Artificial Intelligence Risk Management Framework (AI RMF 1.0), NIST Publication AI 100-1,
# https://nvlpubs.nist.gov/nistpubs/ai/NIST.AI.100-1.pdf.
# 10 Le Mau, T., Hoemann, K., Lyons, S.H. et al. Professional actors demonstrate variability, not stereotypical
# expressions, when portraying emotional states in photographs. Nat Commun 12, 5037 (2021).
# https://doi.org/10.1038/s41467-021-25352-6
#
# Written Comments from Merve Hickok
# In response to Draft Memorandum published in Federal Register 88 FR 75625
#
# 2
#
#
#
#
#
#
#
#
#
#
#
# •  Ban biometric categorization systems: which claim to identify then cluster a person into
# ethnic,  racial,    gender,  political  or  sexual  orientation,  religious  categories  by  using
# biometrics.  These  systems  create  spurious  correlations  between  biometric  data  and
# subjective social constructs.
#
# •  Ban surveillance-related risk assessments about individuals used by law enforcement
# and immigration authorities: which claim to predict future behaviors and actions of an
# individual such as criminal recidivism, offending a person or be a victim of crime. These
# systems create spurious correlations and can be weaponized by authorities under the veneer
# of  ‘objective’  technologies.  Some  of  these  systems  have  already  led  to  unlawful
# decisions.11  These  systems  undermine  human  agency,  human  aspirations,  and  are  in
# conflict of presumption of innocence.
#
# 8. What kind of information should be made public about agencies' use of AI in their annual use
# case inventory?
#
# Guidance suggests CAIO of each agency should have the authority to waive AI systems from the
# minimum requirements. Such powers can create significant loopholes and undermine the whole
# Guidance.
#
# •  Waiver determinations  should be reviewed by an independent authority. No single
#
# person should have complete control or responsibility over waiver decisions.
#
# •  The  issuance  of  such  waivers  should  be  1)governed  by  strict  and  objective  criteria
# 2)include a time limit to avoid indefinite waivers, and 3)include liability mechanisms
# if the waived system later negatively impacted rights or safety.
#
# •
#
# If  and  when  a  waiver  is  issued,  the  time  limit,  evaluation  of  the  agency  against  the
# objective criteria, and justification for the waiver must be disclosed in the public case
# inventory.
#
# •  Terminated AI systems should  be documented in detail in AI Use Case Inventory as
# evidence of assessment, for future accountability purposes, and to serve as lessons learned.
#
# •  Public Incident Reporting: In addition to the existing AI Use Case Inventory, agencies
# should establish a public incident reporting mechanism. Such reporting mechanisms can
# provide lessons to vendors, academic researchers, and state and local level governments.
#
# 11 Robert Koulish & Kate Evans, Punishing With Impunity: The Legacy of Risk Classification Assessment in
# Immigration Detention, 36 Georgetown Immigration Law Journal 1-72 (2021).
# https://scholarship.law.duke.edu/faculty_scholarship/4115 ; Stroud, M. Heat Listed. The Verge. (May 24, 2021).
# https://www.theverge.com/c/22444020/chicago-pd-predictive-policing-heat-list
#
# Written Comments from Merve Hickok
# In response to Draft Memorandum published in Federal Register 88 FR 75625
#
# 3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2.  What  types  of  coordination  mechanisms,  either  in  the  public  or  private  sector,  would  be
# particularly  effective  for  agencies  to  model  in  their  establishment  of  an  AI  Governance  Body?
# What are the benefits or drawbacks to having agencies establishing a new body to perform AI
# governance versus updating the scope of an existing group (for example, agency bodies focused
# on privacy, IT, or data)?
#
# •  An  interdisciplinary  AI  Governance  Body  is  the  right  call.  AI  brings  new  challenges
# which  go  beyond  traditional  IT  software  or  privacy  concerns  due  to  1)the  socio-
# technical  nature  of  these  systems,  2)possibility  for  bias,  and  for  the  system  and  data  to
# change and drift while in use, 3)new risks to human rights and civil rights to emerge based
# on probabilistic and predictive outcomes, and 4)complexities and interdependencies across
# data,  models,  and  outcomes.  AI  systems  can  also  change  the  decision-making  process
# within an agency. Therefore, it is crucial to have a diverse, AI-focused governance body.
#
# •  The AI Governance Body in each agency should have representation from independent
# academia and civil society organizations with human rights and civil rights competence.
#
# •  Mandated Privacy Impact Assessment are outdated. These assessments do not consider
# the ability of AI systems to aggregate data from disparate sources to create granular insights
# about individuals. They also do not take into account the predictive and probabilistic nature
# of AI systems. Therefore, OMB should also consider additional guidance to update PIAs.
#
# •  The agencies should notify the public about planned procurement of a possibly rights-
# impacting  AI  system.  The  agency  should  conduct  public  consultation  and  consult  with
# affected  groups  and  incorporate  their  feedback.  Public  consultation  should  also  be
# conducted during the planned procurement stage, not  only  in  ‘design,  development,
# and use’ stages.
#
# •  Guidance  suggests  “To  the  extent  practicable  and  consistent  with  applicable  law  and
# governmentwide guidance, agencies must consult affected groups, including underserved
# communities, in the design, development, and use of the AI”. Public consultation should
# be mandated for rights-impacting AI systems, not left to a judgement of ‘to the extent
# practicable’.
#
# 3. How can OMB best advance responsible AI innovation?
#
# As  mentioned  above,  I  conducted  interviews  with  20+  government  procurement  practitioners
# involved in AI acquisition. Consistent themes were:
#
# •  Need to implement trustworthy AI during procurement:  The Guidance directs many
# of the ‘minimum practices’ to ‘design, development, and use’ of AI systems. The guidance
# references ‘procured’ AI systems.  This can be interpreted as an “after-the-fact” approach.
# If these practices and controls are only applicable to ‘procured’, government can commit
#
# Written Comments from Merve Hickok
# In response to Draft Memorandum published in Federal Register 88 FR 75625
#
# 4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# taxpayer  funds  for  a  system  which  is  later  found  to  be  uncompliant  with  minimum
# practices.
# These minimum  practices  must  be conducted “during the procurement”  of rights and
# safety impacting AI systems. Commitments of the U.S. government to trustworthy AI must
# be operationalized during the procurement process as well, and not as an afterthought.12
# By  setting  trustworthy  and  responsible  AI  expectations  upfront  with  vendors  and
# contractors, OMB can create fairer competition.
#
# •  Lack  of  government-sanctioned  guidelines  or  resources  to  answer  the  AI-specific
# challenges  and  questions  which  emerge  during  the  procurement  process.  Interviewees
# warned that this either led to risk aversion and a decision not to adopt AI, or procuring AI
# without understanding its limitations, benefits and risks properly.
#
# •  Need  for  agility  and  flexibility  in  AI  procurement  to  reduce  vendor  lock-ins.
# Interviewees  noted  that  incumbent  vendors  had  significant  knowledge  of  federal
# procurement  process  which  gave  them  advantage  over  smaller  vendors.  Even  when
# products of smaller companies performed much better, the existing vendors were able to
# navigate the bureaucracy better and receive contract awards.
#
# •  Federal Data Strategy: While the mandate for agencies to document the provenance and
# quality of the data for its intended purpose is commended, this should be handled in a more
# systematic way. The Federal Data Strategy already provides a framework of operational
# principles and best practices to help agencies leverage consistent data infrastructure and
# strong data governance.13 The Federal Data Strategy includes a set of principles including
# Ethical  Governance,  Conscious  Design,  and  Learning  Culture,  as  well  as  a  set  of  40
# practices to guide agency data management activities. The requirements and best practices
# from the Data Strategy must be operationalized when agencies are making decisions about
# development, use, procurement, and governance of AI systems.
#
# 6.  Do  the  minimum  practices  identified  for  safety-impacting  and  rights-impacting  AI  set  an
# appropriate baseline that is applicable across all agencies and all such uses of AI? How can the
# minimum practices be improved, recognizing that agencies will need to apply context-specific risk
# mitigations in addition to what is listed?
#
# •  Update  procurement  regulation:  Federal  acquisition  regulations  should  be  updated  to
# ensure  these  practices  are  conducted  “during  the  procurement”  of  rights  and  safety
# impacting AI systems.
#
# •  Add  scientific  validity,  contestability  and  traceability  as  required  minimum
# requirements.  AI  systems  used  by  the  government  can  impact  an  individual’s  human
#
# 12 Executive Order 13960, Promoting the Use of Trustworthy Artificial Intelligence in the Federal Government, 85
# FR 78939, (Dec. 8, 2020), https://www.federalregister.gov/documents/2020/12/08/2020-27065/promoting-the-use-
# of-trustworthy-artificial-intelligence-in-the-federal-government
# 13 Office of Management and Budget, Federal Data Strategy - A Framework for Consistency OMB-M-19-18 (June
# 2019). https://www.whitehouse.gov/wp-content/uploads/2019/06/M-19-18.pdf
#
# Written Comments from Merve Hickok
# In response to Draft Memorandum published in Federal Register 88 FR 75625
#
# 5
#
#
#
#
#
#
#
#
#
#
#
#
# rights,  civil  liberties,  safety,  and  access  to  resources.  Therefore,  a  system  used  by  the
# government should have scientific validity and traceability, and the practices should allow
# for contestability.
#
# •  When a decision is made in an agency to use an AI system, documentation should also
# include  other  algorithmic  and  non-algorithmic  alternatives  considered.  Such
# transparency would increase the public’s confidence and trust in the government use of AI.
#
# •  Redress & remedy process should be available without caveats: For rights-impacting
# systems,  the  remedy  process  should  not  place  unnecessary  burden  on  the  impacted
# individual.
#
# •  System-level dependencies: AI systems are dependent on data. Data produced from one
# AI  system  may  be  an  input  to  another  system  in  the  government  infrastructure.  An
# erroneous  or  biased  outcome  from  one  system  can  have  cascading  impact  on  data  and
# outcomes  across  the  system.  This  can  lead  to  discriminatory  government  decisions  on
# individual’s rights, liberties, and access to resources. Therefore, a system design approach
# is required to ensure the data flows and dependencies between the systems are evaluated
# before a system is put into use.
#
# •  Establish  a  procurement  category  code  for  AI/ML  systems:  this  would  allow
# procurement professionals across agencies to know if an existing system or contract can be
# scaled  up.  Currently,  AI  systems  are  procured  by  federal  agencies  using  a  variety  of
# procurement  categories  such  as  software,  consulting  services,  information  technology
# services.  This  disparity  can  result  in  some  systems  put  into  use  without  application  of
# minimum practices.
#
# 7. What types of materials or resources would be most valuable to help agencies, as appropriate,
# incorporate the requirements and recommendations of this memorandum into relevant contracts?
#
# •  Establish  a  menu  of  standard  contract  clauses  which  address  data  quality,  data
# ownership,  data  and  model  access,  AI  model  performance  assurance,  risk  management,
# and mandate  for explainability and auditability of the system. The European Union has
# already drafted EU model contractual AI Clauses to use in procurements of AI and invites
# public  organizations  to  pilot.14  Such  menu  would  help  the  government  procurement
# professionals  and  legal  teams  to  evaluate  and  apply  clauses  consistently  relevant  to  the
# context of the AI system.
#
# As  noted  in  my  congressional  testimony,  we  need  guardrails  in  place  for  AI  systems,  and  the
# expertise in government  to  manage the  consequences of the  rapid  changes that are now taking
#
# 14 European Commission (2023) EU model contractual AI Clauses. https://public-buyers-
# community.ec.europa.eu/communities/procurement-ai/resources/eu-model-contractual-ai-clauses-pilot-
# procurements-ai
#
# Written Comments from Merve Hickok
# In response to Draft Memorandum published in Federal Register 88 FR 75625
#
# 6
#
#
#
#
#
#
#
#
#
#
#
#
# place.15  Guardrails  for  development,  procurement  and  use  of  AI  systems  need  to  reflect
# prioritization  of  human  dignity,  human  rights,  civil  rights,  democratic  values,  and  rule  of  law.
# Governments  must  ensure  alignment  of  policies  and  goals  with  the  tools,  while  ensuring
# government does not lose its independent ability to verify and validate technology vendors’ claims.
#
# Thank you for your consideration of my views. I would welcome the opportunity to discuss these
# recommendations further.
#
# Merve Hickok
# Founder of AIethicist.org
# President and Research Director at Center for AI and Digital Policy (CAIDP)
# Data Ethics Lecturer at University of Michigan, School of Information
#
# 15 Testimony and statement for the record of CAIDP President Merve Hickok, Advances in AI: Are We
# Ready For a Tech Revolution?, House Committee on Oversight and Accountability: Subcommittee on
# Cybersecurity, information Technology, and Government Innovation (Mar. 8, 2023),
# https://oversight.house.gov/wp-content/uploads/2023/03/Merve-Hickok_testimony_March-8th-2023.pdf.
#
# Written Comments from Merve Hickok
# In response to Draft Memorandum published in Federal Register 88 FR 75625
#
# 7
#
# Please find attached written comments from Merve Hickok (AIethicist.org), in response to OMB's Draft Memorandum on Advancing Governance, Innovation, and Risk Management for Agency Use of Artificial Intelligence.

# %%
comments_df
# Out:
#                                                  doc_id        source  \
# 0                                 CAIDP-AI-RFI-2025.pdf  nitrd_ai_rfi
# 1                                            2025-02305  nitrd_ai_rfi
# 2                                  AI_RMF_2nd_draft.pdf    nist_airmf
# 3                                         Accenture.pdf    nist_airmf
# 4                                  Adelin_20Travers.pdf    nist_airmf
# ...                                                 ...           ...
# 2658  part10_all_comments_combined_redacted_oral_not...     cppa_admt
# 2659      ccpa_updates_all_written_comments_p2.pdf#L006     cppa_admt
# 2660  part6_all_comments_combined_redacted_oral_not_...     cppa_admt
# 2661  part5_all_comments_combined_redacted_oral_not_...     cppa_admt
# 2662  part5_all_comments_combined_redacted_oral_not_...     cppa_admt
#
#               collection_id  \
# 0                90-FR-9088
# 1                90-FR-9088
# 2     AI-RMF-2ND-DRAFT-2022
# 3     AI-RMF-2ND-DRAFT-2022
# 4     AI-RMF-2ND-DRAFT-2022
# ...                     ...
# 2658             PR-02-2023
# 2659             PR-02-2023
# 2660             PR-02-2023
# 2661             PR-02-2023
# 2662             PR-02-2023
#
#                                                   title  \
# 0                                 CAIDP-AI-RFI-2025.pdf
# 1     Request for Information on the Development of ...
# 2      second draft of the AI Risk Management Framework
# 3                                             Accenture
# 4                                        Adelin Travers
# ...                                                 ...
# 2658                                          SIRM@SIRM
# 2659                                           APPENDIX
# 2660                  COVINGTON Covington & Burling LLP
# 2661                         Black Business Association
# 2662                  is Message From an Exteral Gender
#
#                                         submitter_name       submitted_at  \
# 0                                                 None               None
# 1                                         OSTP & NITRD         2025-02-06
# 2     second draft of the AI Risk Management Framework               None
# 3                                            Accenture               None
# 4                                       Adelin Travers               None
# ...                                                ...                ...
# 2658                                         SIRM@SIRM  November 22, 2024
# 2659                                          APPENDIX  November 22, 2024
# 2660                 COVINGTON Covington & Burling LLP   November 8, 2024
# 2661                        Black Business Association   November 8, 2024
# 2662                 is Message From an Exteral Gender   November 8, 2024
#
#                                               text_path  \
# 0     data/comments/blobs/a6/a61897bca3e8eb6ba6d4cb1...
# 1     data/comments/blobs/9b/9b6e5baccf22f4e40bfa5eb...
# 2     data/comments/blobs/0b/0b134d057ab06d3a3a014e9...
# 3     data/comments/blobs/43/4370afc6e8a6099d565f382...
# 4     data/comments/blobs/35/350725d68762a101c3a74ae...
# ...                                                 ...
# 2658  /Users/spangher/Projects/stanford-research/rfi...
# 2659  /Users/spangher/Projects/stanford-research/rfi...
# 2660  /Users/spangher/Projects/stanford-research/rfi...
# 2661  /Users/spangher/Projects/stanford-research/rfi...
# 2662  /Users/spangher/Projects/stanford-research/rfi...
#
#                                                    text
# 0     Comments to the \n\nUnited States Office of Sc...
# 1     9088 \n\nFederal  Register / Vol.  90,  No.  2...
# 2     AI Risk Management Framework: Second Draft \n\...
# 3     August 29, 2022 \n\nDr. Laurie E. Locascio   \...
# 4     1/19 \n\nComments  on  the  2nd  draft  of  th...
# ...                                                 ...
# 2658  SIRM@SIRM\nSuse Califoria\nFebruary 19,2025,\n...
# 2659  APPENDIX \n\n20\n\nMODIFIED TEXT OF PROPOSED R...
# 2660  COVINGTON Covington & Burling LLP\nScoseane\na...
# 2661  Black Business Association\nyp pA)\nee\nsonar ...
# 2662  is Message From an Exteral Gender\nhn gs on a ...
#
# [2663 rows x 8 columns]

# %%
comment_responses_parsed = pd.concat([
    comment_responses[['jurisdiction', 'collection_id', 'document_role', 'title']].reset_index(drop=True),
    agg_responses
], axis=1)

# %%
MATCHING_PROMPT = """You are an expert legal assistant. I just finished conducting an RFI, and collected a lot of 
comments from members of the public. My department wrote a long response to these comments, and I am now
trying to go back and determine which comments these responses were specifically responding to. 

I will show you all the notes they made and then I will show you a comment. If one of the responses corresponds to the 
specific comment, please answer with the index of the note that refers to it. If none of the responses corresponds to it, 
please respond with -1.

<notes>
{notes}
</notes>

<comment>
{comment}
</comment>

Your response:
"""

# %%
comment_responses_parsed_w_comments = (
    comment_responses_parsed
        .merge(comments_df[['collection_id', 'doc_id', 'text']], on='collection_id')
)

# %%
SUMM_PROMPT = """Can you summarize the main points of this comment in 2-3 sentences?

{input_text}

Your response:
"""

# %%
summaries = await prompt_utils.process_batch(prompt_template=SUMM_PROMPT, texts=comment_responses_parsed_w_comments['text'])
# Out:
#   0%|          | 0/789 [00:00<?, ?it/s]

# %%
comment_responses_parsed_w_comments['comment_summary'] = summaries

# %%
prompts = (
    comment_responses_parsed_w_comments
         .apply(lambda x: MATCHING_PROMPT.format(
             notes='\n'.join(list(map(lambda y: f"{y[0]}: {y[1]['content_of_comment']}", enumerate(x['responses_to_comments'])))),
             comment=x['comment_summary']
         ), axis=1)
    .tolist()
)

# %%
indices_2 = await prompt_utils.process_batch(prompts=prompts, concurrency=50)
# Out:
#   0%|          | 0/789 [00:00<?, ?it/s]

# %%
(pd.Series(indices) == pd.Series(indices_2)).value_counts()
# Out:
# True     527
# False    262
# Name: count, dtype: int64

# %%
pd.Series(indices_2).value_counts()
# Out:
# -1    510
# 3      96
# 0      68
# 8      61
# 2      18
# 9      15
# 1      14
# 4       5
# 6       1
# 7       1
# Name: count, dtype: int64

# %%
comment_responses_parsed_w_comments['response_index'] = indices
comment_responses_parsed_w_comments['response_index_2'] = indices_2

# %%
matched_comment_response_df = (
    comment_responses_parsed_w_comments
         # .assign(response_index=lambda df: df['response_index_2'])
         .loc[lambda df: df['response_index'].str.isdigit()]
         .assign(response_index=lambda df: df['response_index'].astype(int))
         .assign(responses_to_comments=lambda df: df.apply(lambda x: x['responses_to_comments'][x['response_index']], axis=1))
         .reset_index(drop=True)
         .pipe(lambda df: pd.concat([
             df[['collection_id', 'doc_id']], 
             pd.DataFrame(df['responses_to_comments'].tolist()),
             df[['text', 'comment_summary']]
         ], axis=1))
)

# %%
matched_comment_response_df[['content_of_comment', 'response_to_comment', 'comment_summary']].head(1).to_dict(orient='records')
# Out:
# [{'content_of_comment': 'A number of commenters characterized the definition of NSS as being too broad and expressed concerns that an agency could exempt systems that serve a de minimis national security purpose from implementing the guidance. For example, commenters offered that a potential misuse of the rule would shield AI deployed for rights- impacting or safety-impacting use cases, such as those in law enforcement and immigration.',
#   'response_to_comment': 'OMB takes seriously these comments and acknowledges the public’s concern on this topic. OMB strongly believes that issues of AI governance, innovation, and risk for NSS must be managed appropriately. But given the legal authorities under which this guidance is being issued, it would be inappropriate to include NSS within its scope.  In particular, Section 10.1(i) of Executive Order 14110 directs that, “[t]he initial means, instructions, and guidance issued pursuant to subsections 10.1(a)-(h) of this section”—which include this OMB memorandum—“shall not apply to AI when it is used as a component of a national security system, which shall be addressed by the proposed National Security Memorandum described in subsection 4.8 of this order.” The Executive Order further directs that the National Security Memorandum shall require “specific AI assurance and risk-management practices  for national  security  uses of AI.”  Additionally, the designation of a system as an NSS is not a determination for an agency to make lightly. Federal law defines and limits the grounds upon which a system may be classified as an NSS. Statutes and governmentwide policies, such as National Security Directive 42 and National Security Memorandum 8, establish governance requirements and stringent cybersecurity controls for any system so classified.',
#   'comment_summary': 'Merve Hickok commends OMB’s draft AI guidance and its alignment with democratic values, the AI Bill of Rights, and the NIST AI RMF, but urges stronger safeguards and operationalization of minimum practices during procurement. She recommends banning pseudoscientific and high-risk systems (emotion/ thought/deception detection, biometric categorization, predictive surveillance), requiring scientific validity, traceability, contestability, public consultation, independent review of waivers, incident reporting, and meaningful redress. She also urges updating procurement rules (including an AI procurement category and standard contract clauses), integrating the Federal Data Strategy, and ensuring interdisciplinary governance with civil-society and academic representation.'}]

# %%
matched_comment_response_df[[
    'doc_id',
    'content_of_comment', #'response_to_comment', 
    'comment_summary'
]].iloc[5].to_dict()
# Out:
# {'doc_id': 'OMB-2023-0020-0192',
#  'content_of_comment': 'A number of commenters characterized the definition of NSS as being too broad and expressed concerns that an agency could exempt systems that serve a de minimis national security purpose from implementing the guidance. For example, commenters offered that a potential misuse of the rule would shield AI deployed for rights- impacting or safety-impacting use cases, such as those in law enforcement and immigration.',
#  'comment_summary': 'The comment endorses the Administration’s AI Executive Order and draft OMB guidance but urges that implementation meaningfully center civil rights and equity by building on the AI Bill of Rights—requiring AI systems to be proven safe, effective, and nondiscriminatory before use and adding requirements for notice, explanation, and data privacy. It also calls for adequately resourced agency governance (including empowered CAIOs and labor and civil-rights input), clearer and public rules for waivers and exemptions, stronger procurement safeguards (avoiding harmful surveillance and algorithmic management), pre-deployment guidance for generative AI, and a public inventory of agencies’ AI regulatory authorities.'}

# %%
full_matched_comment_df = pd.concat([
    (comment_responses_parsed_w_comments[['collection_id', 'doc_id', 'text', 'comment_summary']]
         .loc[lambda df: ~df['doc_id'].isin(matched_comment_response_df['doc_id'])]
         .loc[lambda df: df['text'].str.split().str.len() > 50]
         .assign(c=0)
        )
    ,
    matched_comment_response_df.assign(c=1).loc[lambda df: df['text'].str.split().str.len() > 50]
])

# %%
full_matched_comment_df['collection_id'].unique()
# Out:
# array(['OMB-2023-0020', 'PR-02-2023'], dtype=object)

# %%
comment_responses_parsed_w_comments['collection_id'].drop_duplicates()
# Out:
# 0      OMB-2023-0020
# 197       PR-02-2023
# Name: collection_id, dtype: object

# %%
TASK_PROMPT = """You are a helpful legal assistant. 
Summarize the call here in 1-2 sentences. Please express your summary to be read by a member of the public
and tell the public exactly what kind of feedback is being requested. (Please request feedback.)

<call>
{input_text}
</call>

Your response:
"""

# %%
calls = (
    call_response_df
     .loc[lambda df: df['document_role'].isin(['call_overview', 'policy_guidance'])]
     .loc[lambda df: df['collection_id'].isin(['PR-02-2023', 'OMB-2023-0020'])]
)
tasks = await prompt_utils.process_batch(
    texts=calls['preview'].tolist(),
    prompt_template=TASK_PROMPT,
    model='gpt-5'
)

# %%
calls[['collection_id']].assign(call=tasks).reset_index(drop=True)
# Out:
#    collection_id                                               call
# 0  OMB-2023-0020  OMB has issued guidance directing federal agen...
# 1     PR-02-2023  The California Privacy Protection Agency has f...

# %%
(full_matched_comment_df
 .merge(calls[['collection_id']].assign(call=tasks).reset_index(drop=True))
.to_csv('full_matched_comment_df__omb-pr.csv')
)

# %%
full_matched_comment_df
# Out:
#      collection_id                                             doc_id  \
# 0    OMB-2023-0020                                      FR-2023-24269
# 6    OMB-2023-0020                                 OMB-2023-0020-0041
# 7    OMB-2023-0020                                 OMB-2023-0020-0046
# 8    OMB-2023-0020                                 OMB-2023-0020-0043
# 9    OMB-2023-0020                                 OMB-2023-0020-0058
# ..             ...                                                ...
# 319     PR-02-2023  part10_all_comments_combined_redacted_oral_not...
# 320     PR-02-2023      ccpa_updates_all_written_comments_p2.pdf#L006
# 321     PR-02-2023  part6_all_comments_combined_redacted_oral_not_...
# 322     PR-02-2023  part5_all_comments_combined_redacted_oral_not_...
# 323     PR-02-2023  part5_all_comments_combined_redacted_oral_not_...
#
#                                                   text  \
# 0    Federal  Register / Vol.  88,  No.  212 / Frid...
# 6    Wilson Hall \nRoom 220 \nCharlottesville, VA 2...
# 7    Ms. Clare Martorana \nFederal Chief Informatio...
# 8    Sam Daniel J Timothy \nAI Research Scientist \...
# 9    750 9th Street, NW \nWashington, DC 20001 \nww...
# ..                                                 ...
# 319  SIRM@SIRM\nSuse Califoria\nFebruary 19,2025,\n...
# 320  APPENDIX \n\n20\n\nMODIFIED TEXT OF PROPOSED R...
# 321  COVINGTON Covington & Burling LLP\nScoseane\na...
# 322  Black Business Association\nyp pA)\nee\nsonar ...
# 323  is Message From an Exteral Gender\nhn gs on a ...
#
#                                        comment_summary  c  \
# 0    The OMB is seeking public comment on a draft m...  0
# 6    The comment urges the OMB to avoid overburdeni...  0
# 7    The Professional Services Council (PSC) welcom...  0
# 8    The comment urges agencies to adapt roles and ...  0
# 9    The Blue Cross Blue Shield Association support...  0
# ..                                                 ... ..
# 319  SHRM and SHRM California urge the CPPA to adop...  1
# 320  This appendix shows the modified proposed Cali...  1
# 321  CalChamber contends the CPPA’s draft ADMT regu...  1
# 322  The Black Business Association told the CPPA t...  1
# 323  The California African American Chamber of Com...  1
#
#                                     content_of_comment  \
# 0                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# ..                                                 ...
# 319  Comment expresses concern that the revised def...
# 320  Comment raises concerns that the removal of AI...
# 321  Comment expresses concern that the revised def...
# 322  Comment expresses concern that the revised def...
# 323  Previous \n7001(c)\n\n104, 373\n\nComment supp...
#
#                                    response_to_comment
# 0                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# ..                                                 ...
# 319  The Agency disagrees with this comment. The de...
# 320  The Agency disagrees with this comment. The re...
# 321  The Agency disagrees with this comment. The de...
# 322  The Agency disagrees with this comment. The de...
# 323  The Agency notes commenter’s support. The Agen...
#
# [768 rows x 7 columns]

# %% [markdown]
# # EPA Matched Comments

# %%
epa_matched_df = pd.read_csv('full_matched_comment_df__epa.csv', index_col=0)

# %%
epa_matched_df['comment_in_response'].dropna().iloc[10]
# Out:
# "One commenter (IV-D-14) believes the particulate matter emission limits proposed for lime manufacturing kilns and coolers do not represent the maximum achievable control technology and are much less stringent than the limits actually required by the Clean Air Act. The commenter notes that the proposed rule discredits performance test data which demonstrate that particulate emissions of less than half the proposed standard for existing plants are routinely achieved by claiming they may not be consistently achievable, but EPA has provided no statistics. The commenter claims that EPA has chosen instead to base the standards on permit limits, but has selectively eliminated from consideration those permits calling for stringent controls which are currently in place. The commenter gives the examples of Continental Lime which is in compliance with a BACT limit for PM emissions of 0.05 lb/ton limestone, and Western Lime which is in compliance with a permit limit for PM emissions of 0.06 lb/ton limestone. The commenter states, 'Considering just these plants, a recalculation ofthe existing plant limit leads to a standard of 0.09 to 0.11 lb/ton. The new source MACT floor should be no less stringent than 0.05 lb/ton. However, if EPA chooses to establish a MACT floor on the basis of permit limits, it should consider all ofthe permit data in its possession (and available to it through delegated State agencies). It is likely that a lower emission limit would represent the MACT floor and that still lower beyond-the floor alternatives would result.' The commenter notes that if performance data do not represent achievable emission limits, EPA should consider design standards based on air-to-cloth ratios. The commenter also believes the proposed particulate emission limits for grinders, conveyors, and bins are also based on data which overstate emissions (in nearly all cases) and do not represent MACT. The commenter believes EPA should examine actual performance test data test or actual permit limitations."

# %%
epa_matched_df.iloc[10].to_dict()
# Out:
# {'index': 'EPA-HQ-OAR-2002-0052',
#  'comment_in_response': "One commenter (IV-D-14) believes the particulate matter emission limits proposed for lime manufacturing kilns and coolers do not represent the maximum achievable control technology and are much less stringent than the limits actually required by the Clean Air Act. The commenter notes that the proposed rule discredits performance test data which demonstrate that particulate emissions of less than half the proposed standard for existing plants are routinely achieved by claiming they may not be consistently achievable, but EPA has provided no statistics. The commenter claims that EPA has chosen instead to base the standards on permit limits, but has selectively eliminated from consideration those permits calling for stringent controls which are currently in place. The commenter gives the examples of Continental Lime which is in compliance with a BACT limit for PM emissions of 0.05 lb/ton limestone, and Western Lime which is in compliance with a permit limit for PM emissions of 0.06 lb/ton limestone. The commenter states, 'Considering just these plants, a recalculation ofthe existing plant limit leads to a standard of 0.09 to 0.11 lb/ton. The new source MACT floor should be no less stringent than 0.05 lb/ton. However, if EPA chooses to establish a MACT floor on the basis of permit limits, it should consider all ofthe permit data in its possession (and available to it through delegated State agencies). It is likely that a lower emission limit would represent the MACT floor and that still lower beyond-the floor alternatives would result.' The commenter notes that if performance data do not represent achievable emission limits, EPA should consider design standards based on air-to-cloth ratios. The commenter also believes the proposed particulate emission limits for grinders, conveyors, and bins are also based on data which overstate emissions (in nearly all cases) and do not represent MACT. The commenter believes EPA should examine actual performance test data test or actual permit limitations.",
#  'actual_comment': 'See attached\n<<PAGE 1>>\np.1 \n\nOAR Box 1440 \n\nPrepped  by  Ollie Stewart \n\nDocument Number: \n\n96) IV-D-14 \n\nDocket Number: \n\nA-95-41 \n\nPrinted 7/23/2008 9:42:35 AM \n\nSheet 96 of 239\n\n<<PAGE 2>>\nF \n\nP.2 \n\nOfl R-2002-OOS1 \n\n1V-D-IW \n\n517 Creekside Drive \n\nNewark, DE 19711 \nFebruary 15,2003 \n\nLime Manufacturing NESHAP Docket \nEPA Docket Center (Air Docket) \nU.S.  EPA West \nMail Code 61Q2T, Room B108 \n1200 Pennsylvania Avenue, NW \n\nWashington, DC 20460 \n\nAttn: Docket ID No. OAR-2002-0052 \n\nDear Sir: \n\n1 \n\nFEB  |  8  2003 \n\nEPA AIR DOCKET \n\n) 2- 2 1 - 03  A)v--5"3 \n\nIN \n\nThe particulate matter emission limits proposed for lime manufacturing kilns and coolers \ndo not represent the maximum achievable control technology and are much less \nstringent than the limits prescribed by the Clean Air Act.  EPA has chosen to ignore \nperformance test data submitted forthe past 20 years which demonstrate that \nparticulate emissions of less than half the proposed standard for existing plants are \nroutinely achieved.  The proposal discredits these data as representing performance \nthat may not be consistently achievable but has provided no statistics regarding the \nminuscule proportion of unsuccessful performance tests conducted to demonstrate \ncompliance with NSPS, and other permit limitations. \n\nEPA has chosen instead to base the standards on permit limits, but has selectively \neliminated from consideration those permits calling for stringent controls which are in \nplace presently.  Lime manufacturing plants are in compliance with more stringent \nFederally enforceable emission limits than those cited at 67 FR 78058.  As an example \nContinental Lime (MT) is in compliance with a BACT limit of 0.05 lb/ton limestone in \nplace since 1997.  Western Ume (Wl) is in compliance with a limit of 0.06 lb/ton \nlimestone.  EPA has access to all permits containing BACT and PSD determinations but \nhas chosen to omit these limits from its calculations. \n\nConsidering just these plants, a recalculation ofthe existing plant limit leads to a \n\nstandard of 0.09 to 0.11 lb/ton.  The new source MACT floor should be no less stringent \n\nthan 0.05 lb/ton.  However, if EPA chooses to establish a MACT floor on the basis of \n\npermit limits, it should consider all ofthe permit data in its possession (and available to \n\nit through delegated State agencies).  It is likely that a lower emission limit would \n\nrepresent the MACT floor and that still lower beyond-the floor alternatives would result. \n\nIf EPA truly believes that performance test data do not represent achievable emission \nlimits, it should also consider design standards based on (for fabric filters) air to cloth \nratio.  Data from existing facilities is probably available in permits.  If EPA is unable to \nobtain these permits, it should use its authority to obtain the design data from permitted \nfacilities.\n\n<<PAGE 3>>\nF \n\nP.3 \n\nThe particulate matter emission limits proposed for grinders, conveyers and bins are \n\nsimilarly based on data which overstate emissions in nearly all cases and do not \n\nrepresent MACT.  EPA should examine actual performance test data, or as a poor \n\nsubstitute, actual permit limitations.  At a minimum a more stringent new source \n\nparticulate emission standard could be justified. \n\nSincerely, \n\nLouis Wolfe\n',
#  'responses_to_comments': 'The kilns to which the commenter refers are Graymont Western Lime (formerly Continental Lime in Broadwater County, Montana and Western Lime in Green Bay, Wisconsin. The permit limits cited by the commenter were apparently reported on EPA Technology Transfer Network (TTN) website. We contacted the Montana Department of Environment and found that the limit for the kiln in question is actually 0.5 lb/tsf and not 0.05 lb/tsf as reported on the TTN website. Also, the complete permit for Western Lime was located on the Wisconsin Department of Natural Resources website, which showed the permit limit for the kiln in question as being 0.12 lb/tsf rather than the 0.058 lb/tsf as reported on the TTN website. Based on the correct PM permit limits for these two lime sources, our conclusions regarding MACT PM limits for existing and new sources are still appropriate. (As the response to a previous comment shows, these permit limits are also representative of actual performance.) The floor for grinders, conveyors, and bins are based on the existing new source performance standards. We have no data to support a different floor.',
#  'docket_id': nan,
#  'call': nan}

# %% [markdown]
# # Scratch

# %%
import pandas as pd 
import glob
nist_airmf_docs_df = pd.read_json('../data/comments/nist_airmf/AI-RMF-2ND-DRAFT-2022/AI-RMF-2ND-DRAFT-2022.meta.jsonl', lines=True)
uk_ai_proposal = '../data/comments/gov_uk/government_consultations_ai-regulation-a-pro-innovation-approach-policy-proposals/government_consultations_ai-regulation-a-pro-innovation-approach-policy-proposals.meta.jsonl'

# %%
uk_ai_proposal_df = pd.read_json(uk_ai_proposal, lines=True)

# %%
nist_airmf_docs_df.iloc[-1].to_dict()#.iloc[-84]
# Out:
# {'source': 'nist_airmf',
#  'collection_id': 'AI-RMF-2ND-DRAFT-2022',
#  'doc_id': 'nist_airmf_call.html',
#  'title': 'NIST AI RMF Second Draft Call for Comments',
#  'submitter': 'NIST',
#  'submitter_type': 'agency',
#  'org': 'National Institute of Standards and Technology',
#  'submitted_at': NaT,
#  'language': 'en',
#  'urls': {'html': 'https://www.nist.gov/itl/ai-risk-management-framework/comments-2nd-draft-ai-risk-management-framework'},
#  'extra': {'source_url': 'https://www.nist.gov/itl/ai-risk-management-framework/comments-2nd-draft-ai-risk-management-framework',
#   'document_role': 'call'},
#  'kind': 'call'}
