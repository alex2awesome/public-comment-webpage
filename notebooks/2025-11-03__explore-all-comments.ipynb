# %% [markdown]
# # AI Corpus Data Explorer
#
# Explore the harvested consultation corpus. This notebook inspects the folder structure, connector coverage, download/extraction health, and the normalized records used by the application.

# %% [markdown]
# ## Setup & Paths
#
# All harvested content resides in `data/comments/`, while downstream application assets live in `data/app_data/`. Update the cell below if the repository layout changes.
#
# **Key formats**
#
# - `*.meta.jsonl` (produced by `crawl`): one JSON object per line, mirroring the `DocMeta` fields for a collection. Files sit under `data/comments/<connector>/<collection>/<collection>.meta.jsonl`.
#
# - `data/comments/ai_pipeline.sqlite` (download cache): `downloads` table stores one row per fetched document/bundle with `doc_id`, `connector`, `collection_id`, `payload` (JSON), and optional `text_path`/`sha256_text` columns.
#
# - `data/comments/blobs/` (content-addressed text store): each text artefact is written once as `<sha256>.txt`; connectors (e.g., CPPA letters) and the generic `extract` stage reuse this location.
#
# - `data/app_data/ai_corpus.db` (normalized corpus): `documents` table contains the application-facing view. CPPA bundle letters appear here with doc IDs like `part4_all_comments...pdf#L007`, referencing the blob-backed text path.

# %%
from utils import show_text_diff

# %%
import re
import pyperclip

from prompt_utils import (
    async_client,
    sync_client,
    process_batch,
    process_one,
    CLEANER_PROMPT,
    ANALYSIS_PROMPT,
    AI_PROMPT,
    ARGUMENTATION_PROMPT,
)

from reader_utils import load_api_key

load_api_key("/Users/spangher/.openai-reglab-project-key.txt")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from clustering_utils import (
    embed_arguments,
    evaluate_kmeans,
    assign_kmeans_clusters,
    setup_argument_records,
    run_umap_bgmm,
    summarize_bgmm,
    build_contrast_pairs,
)
import prompt_utils as p

# %%
from pathlib import Path
import json
import sqlite3
import itertools
import pandas as pd
import numpy as np

from reader_utils import (
    resolve_project_root,
    get_project_paths,
    connect_export_db,
    load_text_df,
    merge_label_results,
    read_text_blob,
)

pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 160)

PROJECT_ROOT = resolve_project_root()
PATHS = get_project_paths(PROJECT_ROOT)
COMMENTS_ROOT = PATHS['comments_root']
APP_DATA_ROOT = PATHS['app_data_root']
DOWNLOAD_DB_PATH = PATHS['download_db_path']
EXPORT_DB_PATH = PATHS['export_db_path']

print(f'Project root : {PROJECT_ROOT}')
print(f'Comments root: {COMMENTS_ROOT}')
print(f'App data root: {APP_DATA_ROOT}')
print(f'Download DB  : {DOWNLOAD_DB_PATH}')
print(f'Export DB    : {EXPORT_DB_PATH}')

text_df = load_text_df(EXPORT_DB_PATH, PROJECT_ROOT)
text_df['source'].value_counts()

# %%
source_sql = """
    SELECT
          source,
          collection_id,
          COUNT(*) AS documents,
          SUM(CASE WHEN text_path IS NOT NULL THEN 1 ELSE 0 END) AS docs_with_text,
          SUM(CASE WHEN pdf_path IS NOT NULL THEN 1 ELSE 0 END) AS docs_with_pdf
      FROM documents
      GROUP BY source, collection_id
      HAVING COUNT(*) > 10
      ORDER BY documents DESC;
"""
source_summary = pd.read_sql(source_sql, export_conn)
source_summary
# Out:
#                      source                                      collection_id  documents  docs_with_text  docs_with_pdf
# 0           regulations_gov                                     NTIA-2023-0005       1452            1452            274
# 1                 cppa_admt                                         PR-02-2023        592             592            592
# 2  eu_have_your_say_playwright  _info_law_better-regulation_have-your-say_init...        438             438              0
# 3           regulations_gov                                     NTIA-2023-0009        335             335            121
# 4           regulations_gov                                      OMB-2023-0020        197             197            146
# 5                nist_airmf                              AI-RMF-2ND-DRAFT-2022         85              85             84
# 6    hand_curated_responses                         uk_ai_regulation_responses         31              31             15

# %% [markdown]
# # Affiliation of the commenter

# %%
text_df = pd.read_csv('processed_dataset.csv', index_col=0).reset_index(drop=True)
text = text_df['clean_text'].iloc[4]
test_batch = await process_batch(text_df['clean_text'], ANALYSIS_PROMPT, concurrency=500)

# %%
top_collections = text_df['collection_id'].value_counts().loc[lambda s: s > 1].index

# %%
f, ax = plt.subplots(1, 1, figsize=(4,2))
(text_df
 .loc[lambda df: df['collection_id'].isin(top_collections)]
 .assign(text_len=lambda df: df['text'].str.split().str.len())
 .pipe(lambda df: 
       sns.boxplot(
           data=df, 
           x='text_len', 
           y='collection_id', 
           order=df.groupby('collection_id')['text_len'].median().sort_values(ascending=False).index,
           showfliers=False
       ),
      ) 
)
ax.set_ylabel('')
ax.set_xlabel('Average length of comment (# words)')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
test_batch_parsed = list(map(json.loads, test_batch))
text_df_with_labels = merge_label_results(text_df, test_batch_parsed)

# %%
comment_counts = text_df_with_labels['label'].value_counts()
top_orgs = comment_counts.head(15).index.tolist()

# %%
import seaborn as sns

# %%
ax = (
    argument_records
     .drop_duplicates('doc_id')['label']
     .value_counts()
     .loc[lambda s: s > 10].iloc[::-1].plot(kind='barh', figsize=(2,4))
)
plt.ylabel('')
plt.xlabel('Count of groups')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
ax = (
    text_df_with_labels
         .assign(text_len=lambda df: df['clean_text'].str.split().str.len())
         .loc[lambda df: df['label'].isin(top_orgs)]
         .pipe(lambda df: 
               sns.boxplot(
                   data=df, 
                   x='text_len', 
                   y='label', 
                   order=df.groupby('label')['text_len'].median().sort_values(ascending=False).index,
                   showfliers=False
               ),
              )
)
ax.set_ylabel('')
ax.set_xlabel('Average length of comment (# words)')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %% [markdown]
# # Is about AI

# %%
test_one = process_one(text_df["clean_text"].iloc[0], AI_PROMPT)
test_one
# Out:
# 'Yes — the comment responds to proposed California regulations governing automated decisionmaking technologies (ADMT) and AI-related activity, addressing definitions, pre-use notices, opt-outs, access rights, risk assessments, and calls for harmonization with other AI laws and regulators.'

# %% [markdown]
# # Argumentation

# %%
argumentation_batch = await process_batch(text_df["clean_text"].tolist(), ARGUMENTATION_PROMPT, concurrency=500)
text_df['arguments'] = argumentation_batch

# %%
SNIPPET_PROMPT = """You are an expert policy analyst. You will receive a policy comment and a list of {k} arguments drawn from that
  comment. For each argument:

  - Find 1-2 snippets copied from the comment that BEST support it.
  - Copy the snippets verbatim (no edits, no paraphrasing).
  - If you find >1 snippets, join them with a single newline (\n).

  Format your response as follows:

  1. Snippets corresponding to each argument are numbered (1., 2., …).
  2. Separate numbered entries with \n\n.
  3. Do not insert or copy over blank lines anywhere else.
  <comment text>
  {comment_text}
  </comment text>
  <arguments>
  {arguments}
  </arguments>
"""

# %%
args_formatted = (
    text_df['arguments']
        .str.split('\n\n').apply(lambda x: list(map(lambda y: f"{y[0] + 1}: {y[1]}", enumerate(x))))
)
k = args_formatted.str.len()
args_formatted = args_formatted.str.join('\n')

# %%
prompts = list(map(
    lambda x: SNIPPET_PROMPT.format(k=x[2], arguments=x[1], comment_text=x[0]), 
    zip(text_df['clean_text'].tolist(), args_formatted.tolist(), k.tolist())
))

# %%
snippets = await p.process_batch(prompts=prompts, check_additional=[p.numbered_list_checker], max_attempts=10)

# %%
text_df['snippets'] = snippets

# %%
text_df.to_csv('processed_dataset.csv')

# %% [markdown]
# ### Clustering comments

# %%
argument_records = setup_argument_records(text_df, text_df_with_labels)
# argument_records, sampled_indices = downsample_argument_records(argument_records, max_samples=5000, random_state=42)
# print(f"Using {len(argument_records)} arguments (downsampled from {len(argument_records)})")

snippet_exploded = (
    text_df[['doc_id', 'snippets']]
         .assign(snippets=lambda df: df['snippets'].str.split('\n\n'))
         .explode('snippets')
         .assign(snippet_num_in_doc=
                 lambda df: df['snippets'].str.strip()
                                 .str.split()
                                 .str.get(0).str.replace('.', '')
                                 .apply(lambda x: int(x) if (pd.notnull(x) and x.isdigit() ) else None)
                )
         .dropna()
         .assign(snippet_num_in_doc=lambda df: df['snippet_num_in_doc'].astype(int))
)

argument_records['arg_num_in_doc'] = argument_records.groupby('doc_id')['argument_id'].rank(method='dense').astype(int)
argument_records = argument_records.merge(
    snippet_exploded, left_on=['doc_id', 'arg_num_in_doc'], right_on=['doc_id', 'snippet_num_in_doc'], how='left'
)
argument_records['snippets'] = argument_records['snippets'].str.replace(r'^\d+\.', '', regex=True)

# %%
f, ax = plt.subplots(1, 1, figsize=(4,1))
sns.boxplot(x=argument_records['doc_id'].value_counts(), showfliers=False, ax=ax)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel('Count of arguments in comment')
# Out:
# Text(0.5, 0, 'Count of arguments in comment')

# %%
t = argument_records[['argument', 'snippets']].sample(5)

# %%
t.iloc[1:][['snippets', 'argument']].assign(snippets=lambda df:  '...' + df['snippets'] + '...').rename(columns={'snippets': 'snippet of comment'})
# Out:
#                                                                                                                                                                                                                                               snippet of comment  \
# 9488      ... AI companies use art assets without artists' permission in order to replicate their work for free.\nIt's nothing more than an elaborate form of plagiarism that attempts to obscure the identities of the victims by collaging pieces together....
# 10677  ... Any effective AI accountability system must include companies disclosing the training data used, especially copyrighted training data, to trail ML models.\nPlease require and enforce disclosure, as other responsible governments appear to be d...
# 5500   ... If a government or organization may wish to create a new impact assessment, it is advised that the assessment capture risk, cover the entire lifecycle, operate in a multistakeholder fashion, and assist with go/no-go decisions.\n“This program ...
# 241    ... They need clear, thoughtful mies that consider their needs and limitations, as well as how they use digital tools to keep their businesses thriving.\nWe urge the CPPA to more carefully consider the impact and costs of the proposed regulations...
#
#                                                                                                                                                                                  argument
# 9488                            Unauthorized appropriation / copyright theft: AI systems train on and reproduce artists' work without permission, which is framed as plagiarism or theft.
# 10677  Transparency/Accountability: Argues that companies should be required to disclose training data so regulators and the public can audit, trace, and hold AI developers accountable.
# 5500                                                Procedural, risk‑based preference: Favors flexible, impact‑assessment driven processes over prescriptive, sector‑specific regulation.
# 241                                  Proportionality/tailoring plea: Calls for balanced, scaled regulations that consider small business capacities and avoid one-size-fits-all mandates.

# %%
argument_embeddings = embed_arguments(argument_records["argument"].tolist(), sync_client)
from umap import UMAP
umap_model = UMAP(n_components=15, metric="cosine", min_dist=0.1, random_state=42)
umap_embeddings = umap_model.fit_transform(argument_embeddings)

# %%
max_k = max(3, min(25, len(argument_records)))
k_values = range(2, max_k)
kmeans_eval = evaluate_kmeans(umap_embeddings, k_values)
kmeans_eval

# %%
best_kmeans = kmeans_eval.attrs.get("best_model")
if best_kmeans is None:
    raise RuntimeError("No best KMeans model found. Check kmeans_eval.")
cluster_summary, representatives = assign_kmeans_clusters(argument_records, umap_embeddings, best_kmeans)
cluster_summary.head(10)

# %%
reduced_embeddings, bgmm_labels, bgmm_probs, bgmm_silhouette = run_umap_bgmm(
    argument_embeddings,
    n_components=min(80, len(argument_records)),
    umap_kwargs={"n_components": 15, "metric": "cosine", "min_dist": 0.1},
    weight_concentration_prior=0.1,
)

# %%
bgmm_summary = summarize_bgmm(argument_records, argument_records['bgmm_cluster'], argument_records['bgmm_posterior'])
print(f"BGMM silhouette (UMAP space): {bgmm_silhouette:.4f}")
# Out:
# BGMM silhouette (UMAP space): 0.3655

# %%
argument_records['bgmm_cluster'] = bgmm_labels
argument_records['bgmm_posterior'] = bgmm_probs

# %% [markdown]
# ### summarizing comments

# %%
SUMMARIZATION_PROMPT = """You are an expert policy analyst summarizing statements about AI legislation.
I will give you a set of descriptions, that I clustered because they represented the same topic.
Please output a single, concise summary (one-sentence), emphasizing keywords and condensing the descriptions (~20 words).

<descriptions>
{input_text}
</descriptions>
"""

SHORT_SUMMARIZATION_PROMPT = """You are an expert policy analyst summarizing statements about AI legislation.
I will give you a set of descriptions, that I clustered because they represented the same topic.
Please output a single, VERY concise keyword summary (1-3 words), condensing the descriptions.

<descriptions>
{input_text}
</descriptions>
"""

cluster_records = (
    argument_records
         .groupby('bgmm_cluster')
         .apply(lambda df: df.sort_values('bgmm_posterior', ascending=False).head(10)['argument'])
         .groupby(level=0)
         .aggregate(list)
)

cluster_summaries = await process_batch(cluster_records.str.join('\n').tolist(), SUMMARIZATION_PROMPT)
cluster_summaries = pd.Series(cluster_summaries, index=cluster_records.index)

keyword_cluster_summaries = await process_batch(cluster_records.str.join('\n').tolist(), SHORT_SUMMARIZATION_PROMPT)
keyword_cluster_summaries = pd.Series(keyword_cluster_summaries, index=cluster_records.index)

cluster_summary_concat = pd.concat([keyword_cluster_summaries.to_frame('keyword'), cluster_summaries.to_frame('summary')], axis=1)
# Out:
# /var/folders/xh/qnyq7yzj0r328_7hnb7pgxth0000gp/T/ipykernel_1255/744081245.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda df: df.sort_values('bgmm_posterior', ascending=False).head(10)['argument'])
#   0%|          | 0/80 [00:00<?, ?it/s]
#   0%|          | 0/80 [00:00<?, ?it/s]

# %%
cluster_samples = (
    argument_records
         .groupby('bgmm_cluster')
         .apply(lambda df: df.sort_values('bgmm_posterior', ascending=False).head()[['argument', 'snippets', 'label']])
).reset_index().drop(columns='level_1')

top_arguments_by_cluster = cluster_samples.groupby('bgmm_cluster')[['argument', 'snippets']].aggregate(list)
# Out:
# /var/folders/xh/qnyq7yzj0r328_7hnb7pgxth0000gp/T/ipykernel_1255/3439075035.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda df: df.sort_values('bgmm_posterior', ascending=False).head()[['argument', 'snippets', 'label']])

# %%
cluster_summary_concat.head(10)
# Out:
#                                   keyword  \
# bgmm_cluster
# 0                   Enforcement authority
# 1                       Labor protections
# 2                           Staged access
# 3             Technological inevitability
# 4                  Regulatory duplication
# 5                       Youth protections
# 6                    Risk-proportionality
# 7                Consent and Compensation
# 8                        Expert authority
# 9                            Audit trails
#
#                                                                                                                                                                                                 summary
# bgmm_cluster
# 0                                                 Mandate firm benefit–risk documentation and give regulators statutory duties plus authority to review, challenge, and prohibit harmful AI processing.
# 1             Require labor protections for moderators, annotators, crowdworkers (including volunteers), with mental‑health safeguards, fair pay, supply‑chain accountability, safe working conditions.
# 2                                           Advocate staged, tiered, or structured access (APIs, vetted research access) as a middle path—recognizing weight-release irreversibility and leakage risks.
# 3                              Argues AI's technological inevitability and ubiquity make strict regulation futile, risking innovation chill, industry/talent flight, and economic competitiveness loss.
# 4                        Warns the proposal duplicates NAIC, NIST/ISO, and statutory frameworks prematurely, creating overlapping audits, inconsistent definitions, and unnecessary compliance burdens.
# 5                     Require heightened protections for minors and vulnerable populations: age-based safeguards, sensitive-data rules, parental consent, and provider responsibility against AI harms.
# 6                                          Adopt a risk‑based, proportional regulatory approach: scale obligations to system risk, context, and resources—lighter for low‑risk, stricter for high‑risk.
# 7                                                                           Mandate explicit CONSENT and FAIR COMPENSATION for creators whose works train AI, with opt‑in licensing and removal rights.
# 8                                                  Urges policymakers to consult AI experts and institutions (e.g., IEEE), relying on expert consensus to legitimize urgent, safety-focused regulation.
# 9                Require comprehensive, tamper‑resistant documentation and recordkeeping—logs, provenance, versioning, inputs/outputs, and retention schedules—to ensure traceability and auditability.

# %%
cluster_identity_distribution = (
    bgmm_summary['dominant_labels']
        .apply(pd.Series).fillna(0).pipe(lambda df: df.divide(df.sum(axis=1), axis=0)).sort_index()
        .sort_values(['individual_citizens', 'industry_associations']).copy()
)

labels = (
    keyword_cluster_summaries
        .to_frame('keyword')
        .reset_index().rename(columns={'bgmm_cluster': 'cluster'})
        .apply(lambda x: f"C{x['cluster']}: {x['keyword']}", axis=1)
)

fig, ax = plt.subplots(figsize=(10, 14))
left = np.zeros(len(cluster_identity_distribution))

for column in cluster_identity_distribution.columns:
    ax.barh(
        labels,
        cluster_identity_distribution[column],
        left=left,
        label=column,
    )
    left += cluster_identity_distribution[column]

ax.set_xlabel("% groups")
ax.set_xlim(0, 1)
ax.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %%
import clustering_utils as c
cluster_idx, distances = c.cluster_centroid_distance_matrix(argument_embeddings, argument_records['bgmm_cluster'].tolist())

# %%
cluster_diff_df = pd.DataFrame(distances, index=cluster_idx, columns=cluster_idx)
cluster_diff_df = (
    cluster_diff_df
        .pipe(lambda df: pd.DataFrame(np.triu(df), index=df.index, columns=df.columns))
        .unstack()
        .sort_values(ascending=False)
        .to_frame('distance')
        .reset_index()
        .rename(columns={'level_0': 'cluster_0', 'level_1': 'cluster_1'})
        .loc[lambda df: df['distance'] > 0]
)

# %%
cluster_diff_df_w_summaries = (
    cluster_diff_df
         .merge(top_arguments_by_cluster.rename(columns=lambda x: x + '_0'), left_on='cluster_0', right_index=True)
         .merge(top_arguments_by_cluster.rename(columns=lambda x: x + '_1'), left_on='cluster_1', right_index=True)
)

# %%
input_text = (
    cluster_diff_df_w_labels_and_summs
        .apply(lambda x: 
   """<statement 1>
{statements_1}
</statement 1>
   
<statement 2>
{statements_2}
</statement 2>""".format(
          statements_1=f"{x['keyword_0']}: {x['summary_0']}",
          statements_2=f"{x['keyword_1']}: {x['summary_1']}",
      ), axis=1)
    )

# %%
CONTRAST_PROMPT = """You are an expert policy analyst comparing two sets of statements about AI legislation.
We picked these arguments to be different, but we're not sure if they are relevant to each other.
Determine whether the statements agree, disagree, or are neutral.

* "agree" is when two stances support each other or argue for the same goal.
* "disagree" is when two stances are on the same issue, directly contrast with each other, and argue for opposite goals.
* "neutral" is when two stances are not relevant to each other.

Respond with JSON {{"label": "...", "reason": "..."}} where label is one of ["disagreement", "agreement", "neutral"].

{input_text}
"""
# contrast_outputs = await process_batch(pair_inputs, prompt=CONTRAST_PROMPT, concurrency=8, check_json=True)
# contrast_results = pd.DataFrame([{**meta, **json.loads(output)} for meta, output in zip(pair_metadata, contrast_outputs)]).sort_values("distance", ascending=False)
# contrast_results.head()

# %%
contrast_outputs = await p.process_batch(input_text.tolist(), CONTRAST_PROMPT, concurrency=500, check_json=True, model='gpt-5')
# Out:
#   0%|          | 0/1128 [00:00<?, ?it/s]

# %%
contrast_outputs = list(map(json.loads, contrast_outputs))

# %%
contrast_outputs_df = pd.DataFrame(contrast_outputs)

# %%
contrast_outputs_df['label'].value_counts()
# Out:
# label
# neutral         631
# agreement       403
# disagreement     94
# Name: count, dtype: int64

# %%
cluster_diff_df_w_labels = pd.concat([cluster_diff_df_w_summaries, contrast_outputs_df], axis=1)

# %%
cluster_diff_df_w_labels_and_summs = (
    cluster_diff_df_w_labels
         .merge(keyword_cluster_summaries.to_frame('keyword_0'), left_on='cluster_0', right_index=True)
         .merge(keyword_cluster_summaries.to_frame('keyword_1'), left_on='cluster_1', right_index=True)
         .merge(cluster_summaries.to_frame('summary_0'),  left_on='cluster_0', right_index=True)
         .merge(cluster_summaries.to_frame('summary_1'),  left_on='cluster_1', right_index=True)
)

# %%
pd.options.display.max_colwidth = 250

# %%
cluster_disagreement_samples = (
    cluster_diff_df_w_labels_and_summs
         .loc[lambda df: df['label'] == 'disagreement']
         [['reason','keyword_0', 'summary_0', 'snippets_0', 'keyword_1', 'summary_1', 'snippets_1']]
         .head(5)
)

# %%
for _, row in cluster_disagreement_samples.iterrows():
    row
    print(f"""
{row['keyword_0']}: {row['summary_0']}

    <disagrees with>

{row['keyword_1']}: {row['summary_1']}

Reason: 
{row['reason']}

Examples Statement 1: 
{'...' + '...\n...'.join(row['snippets_0'][:3]) + '...'}

Examples Statement 2:
{'...' + '...\n...'.join(row['snippets_1'][:3]) + '...'}
    """)

    print('\n===============================================================\n')
# Out:
# Creators' livelihoods: Unlicensed AI training on artists’ work threatens livelihoods and copyrights, enabling large companies’ economic exploitation and concentrating profits, harming small creators.
#
#     <disagrees with>
#
# Regulatory sandboxes: Promote regulatory sandboxes and flexible, case-by-case, voluntary governance to foster SME‑accessible innovation, fair transparent access, and risk‑managed R&D.
#
# Reason:
# Statement 1 advocates protecting IP within AI legislation and favors a non‑prescriptive approach, while Statement 2 seeks to strip IP rights from AI-generated outputs (public domain) and bar commercialization. These positions conflict on the treatment of IP in AI.
#
# Examples Statement 1:
# ... are now using artists stolen life works to steal their livelihood for the rest of their lives and also rob future generations of potential artists that won’t be able to afford to pursue art because the industry is ruined.
# millions and millions of coders, artists, writers, musicians, journalists, and more will lose their jobs and the whole world will suffer....
# ... The data scraping to train AI systems needs to be regulated to protect copyrighted works and personal data.
# So, artwork may be used to produce derivative work without the artists' permission, which undermines the artists' effort and value....
# ... The plague of AI scraping data from sites is undermining creatives, outright theft, and incredibly hard to trace back.
# It's a grift created by people that want all of the benefits of everyone else's hard work....
#
# Examples Statement 2:
# ... Here, the proposed regulatory sandboxes should be put into use.
# Put regulatory sandboxes into proper use when developing common specifications for AI....
# ... Recommendation 3.4: Deliver targeted support to SMEs:
# Recognising SMEs' unique data challenges, the Government should establish channels for all SMEs to access high-quality public data, promoting innovation and growth. Trusted data stewards could aid in this process. Moreover, SMEs should be represented in expert groups to provide first-hand insights. We also endorse the ICO's call for further research on optimal guidance for SMEs. Competition regulators should proactively ensure that AI technologies cannot operate behind a 'moat' of protected proprietary data, standards, and frameworks, and that there is governance of common data pools and reporting frameworks to permit the development of an open and competitive market for AI tech providers.
# 112. Public data, spanning court records to regulatory updates, holds critical value. These datasets can provide the necessary resources for SME law firms to innovate, develop more sophisticated legal tech solutions, and improve their legal service offering. A data-driven approach to legal practice can drive significant growth and scalability....
# ... The question is whether the AI real laboratories (sandboxes), as provided for in Article 53 et seq., should be extended in the context of constitutional admissibility (equality) in order to enable SMEs to develop innovative AI systems and also to test them in practice....
#
#
# ===============================================================
#
#
# Job displacement: AI-driven automation threatens job displacement across sectors—especially creative and low‑wage work—exacerbating income inequality, wage pressure, and wealth concentration.
#
#     <disagrees with>
#
# Transparency vs IP: Balance transparency and accountability with protections for trade secrets, IP, privacy, and cybersecurity—allow controlled disclosures and limits to mandatory transparency.
#
# Reason:
# Statement 1 favors light‑touch, flexible, non‑prescriptive regulation to protect innovation, while Statement 2 proposes a strict, prescriptive rule (no copyright, no commercialization of AI outputs). The latter would impose significant constraints likely at odds with the pro‑innovation, minimal‑burden approach in Statement 1.
#
# Examples Statement 1:
# ... it will further the inequality gap and divide us even more....
# ... I worry about the impact that AI will have on employment.
# Implementing AI too quickly, without oversight, could lead to a loss of meaningful jobs....
# ... In the case of artists and authors, they may lose what little income they currently draw should large studios, publishing companies, or any other place of employment which normally requires a creative mind suddenly begins using AI as it's imaginative core rather than a human mind.
# This is a classic example of "the rich get richer, the poor get poorer", but this time it faces a distinct future where humans are reduced to the be the labor machine whereas the machine becomes the creative "genius"....
#
# Examples Statement 2:
# ... "Additionally, the proposed regulations add new language to clarify that businesses providing pre-use notices or responding to access requests are not required to disclose trade secrets or information that may compromise their ability to protect against security threats and illegal activity. We strongly recommend keeping these provisions and strengthening them as described below. (Section 7220(d), Section 7222(c).)"
# "Specifically, it should protect “intellectual property or other confidential information,” in addition to protecting trade secrets, to help ensure that companies can comply with the proposed regulations without putting at risk their business operations."
# "Recommendation: • A new provision should state: Confidentiality. Risk assessment materials disclosed to the Agency are to be treated as confidential by default and are exempt from open records laws. In addition, providing materials to the Agency does not constitute a waiver of attorney-client privilege, work product protection, or other applicable protections."...
# ... Since we are talking about harm to people, notions of NDA and IP as a blocker to audit is ridiculous. The extent to which AI companies will be noncompliant reveals an intense hunger for profit....
# ... protecting personal information: improving the processes for removing personal information from the register
# protecting personal information on the register...
#
#
# ===============================================================
#
#
# Attachment-only: Attachment-only administrative submissions: commenters reference attached feedback but provide no substantive arguments on AI legislation, leaving positions indeterminate.
#
#     <disagrees with>
#
# Restrict data exploitation: Demand the agency adopt STRONGER SAFEGUARDS—rejecting INDUSTRY ROLLBACKS—to curb BIG TECH data scraping and CORPORATE EXPLOITATION, prioritizing PUBLIC INTEREST.
#
# Reason:
# Statement 1 advocates prescriptive mandates (opt-in consent/licensing, mandatory compensation, updated IP laws) to prioritize creators’ rights, which imposes procedural requirements on AI training/use. Statement 2 calls for light‑touch, principles‑led, proportionate regulation that avoids prescriptive rules and procedural burdens to protect innovation. These regulatory philosophies point in opposite directions on how stringent AI rules should be.
#
# Examples Statement 1:
# ... see attached file
# EN (321.6 KB - PDF - 1 page) Download...
# ... Please see attached document.
# (333.8 KB - PDF - 1 page)...
# ... Feedback from: Center for Data Innovation
# The Center for Data Innovation is pleased to respond to the European Commission’s request for feedback on the Artificial Intelligence Act. Please see the enclosed document for our comments....
#
# Examples Statement 2:
# ... Tote california Privay Protection gency,
# pleased tached the comments CTIAn pons othe gene Note of Madeatons to Proposed Parlin repeengCoaupdne, joes non and auarce eins...
# ... These rule should elec the needs of everyday peopo to be protected fom <isriination and data sraping, not Bi Tet’ appetite for prftng rom our personal into...
# ... These rules should reflec the ned of everyday people tobe protected fom discrimination and data scraping, not Big Tects appetite for potting from our personal info...
#
#
# ===============================================================
#
#
# Central coordination: Calls for a central coordinating body—independent regulator or hub—providing coordination, horizon‑scanning, registers, data‑sharing, and enforcement/statutory backing to avoid fragmented regulation.
#
#     <disagrees with>
#
# Attachment-only: Attachment-only administrative submissions: commenters reference attached feedback but provide no substantive arguments on AI legislation, leaving positions indeterminate.
#
# Reason:
# Statement 1 advocates broad, mandatory lifecycle and supply‑chain accountability for AI systems, implying expansive regulation. Statement 2 argues the agency’s AI rules are ultra vires and should be narrowed or punted to the legislature. They pull in opposite directions on the scope and authority of AI regulation, with Statement 2 resisting the kind of expansive mandate envisioned by Statement 1 (at least at the agency level).
#
# Examples Statement 1:
# ... The UK government and the central function can play a key role in convening and coordinating regulators, and facilitating the sharing of information.
# As such, presumably the central function can play a valuable role in convening regulators, hosting discussions, identifying points of tension and facilitating the sharing of information, but cannot override or direct sectoral authorities’ decisions. (This would presumably require primary legislation if it were to become the policy intent)....
# ... We recognise that concerns regarding the fragmented regulation which is currently in place would benefit from central coordination and oversight. Failing to do so leads to a danger of creating clashing and confusing guidelines which inadvertently allow for copyright infringement issues in some sectors to slip through the net.
# Strengthening the role of the UK IPO and resourcing it to take on new coordinating and enforcement responsibilities in regard to AI & copyright would also be of likely benefit to avoid the creation of overlapping, duplicative or contradictory guidance on AI....
# ... Yes, we think this would be helpful to mandate a duty on regulators to have due regard to the principles via statute. This would create greater consistency centrally across regulators and the regulatory landscape, which needs to be considered to provide useful guidance to businesses and consumers. However, the success of this is also contingent on the strength of the legal obligation.
# In broad terms we agree, these are clearly functions that are best delivered centrally to provide a coordinated and coherent approach. We agree with the statement that delivering some functions centrally provides the UK Government with an overarching view of how the framework is working, where it is effective and where it may require improvement (White Paper, paragraph 72). This is even more important when considering that there may be AI-related risks that do not clearly fall within the remits of the UK’s existing regulators (White Paper, paragraph 64) and that there could be overlapping, duplicative or contradictory guidance on AI issued by different regulators....
#
# Examples Statement 2:
# ... see attached file
# EN (321.6 KB - PDF - 1 page) Download...
# ... Please see attached document.
# (333.8 KB - PDF - 1 page)...
# ... Feedback from: Center for Data Innovation
# The Center for Data Innovation is pleased to respond to the European Commission’s request for feedback on the Artificial Intelligence Act. Please see the enclosed document for our comments....
#
#
# ===============================================================
#
#
# Regulatory overreach: Alleges regulatory overreach/ultra vires: agency exceeds statutory authority by broadly regulating AI/ADMT, cybersecurity, profiling, and advertising beyond its mandate.
#
#     <disagrees with>
#
# Creators' livelihoods: Unlicensed AI training on artists’ work threatens livelihoods and copyrights, enabling large companies’ economic exploitation and concentrating profits, harming small creators.
#
# Reason:
# Statement 1 advocates stronger, enforceable oversight with empowered regulators and no self-certification. Statement 2 criticizes agency efforts as ultra vires and urges narrowing rules, pushing back against expanded regulatory action. While both mention statutory bases, the practical thrusts conflict: expand/empower oversight versus curb current regulatory reach.
#
# Examples Statement 1:
# ... BPI appreciates changes made by the Agency to the proposed cybersecurity audit rules, particularly those that seem motivated by interoperability with recognized industry standards, such as those published by the National Institute of Standards and Technology.  However, the Agency still lacks the statutory authority to adopt a prescriptive set of affirmative cybersecurity requirements.
# Preliminarily, the Agency does not have authority under the auspices of regulating automated decision-making to regulate training of systems....
# ... we are concerned that CPPA has overstepped its mandate by drafting regulations that extend beyond merely auditing practices and instead establish a comprehensive framework for governing company cybersecurity practices. This overreach not only exceeds the CPPA's granted authority but also imposes undue burdens on sectors that already adhere to robust cybersecurity standards.
# By prescribing detailed cybersecurity practices, the CPPA is  assuming regulatory responsibilities that may extend beyond its jurisdiction....
# ... Finally, the proposed regulations seek to regulate how businesses across the state use technology to help them make decisions across a wide range of topics, including lending, housing, education, employment, healthcare, and various consumer goods, without sufficiently connecting those regulations to the agency’s privacy mandate.
# The agency is a privacy regulator, not a housing regulator or an employment regulator (or even an automated-technology regulator), so the agency’s regulations must be narrowed to focus on business activities that carry genuine consumer-privacy risks....
#
# Examples Statement 2:
# ... are now using artists stolen life works to steal their livelihood for the rest of their lives and also rob future generations of potential artists that won’t be able to afford to pursue art because the industry is ruined.
# millions and millions of coders, artists, writers, musicians, journalists, and more will lose their jobs and the whole world will suffer....
# ... The data scraping to train AI systems needs to be regulated to protect copyrighted works and personal data.
# So, artwork may be used to produce derivative work without the artists' permission, which undermines the artists' effort and value....
# ... The plague of AI scraping data from sites is undermining creatives, outright theft, and incredibly hard to trace back.
# It's a grift created by people that want all of the benefits of everyone else's hard work....
#
#
# ===============================================================

# %%
row
# Out:
# reason        Statement 1 seeks prescriptive, mandatory measures (opt-in licensing, compensation, strengthened IP rules) for AI training/use, while Statement 2 advocates light-touch, non‑prescriptive, low‑burden regulation to protect innovation. These position...
# keyword_0                                                                                                                                                                                                                                               Attachment-only
# summary_0                                                                                   Attachment-only administrative submissions: commenters reference attached feedback but provide no substantive arguments on AI legislation, leaving positions indeterminate.
# snippets_0    [ see attached file\nEN (321.6 KB - PDF - 1 page) Download,  Please see attached document.\n(333.8 KB - PDF - 1 page),  Feedback from: Center for Data Innovation\nThe Center for Data Innovation is pleased to respond to the European Commission’s r...
# keyword_1                                                                                                                                                                                                                                    Restrict data exploitation
# summary_1                                                                                             Demand the agency adopt STRONGER SAFEGUARDS—rejecting INDUSTRY ROLLBACKS—to curb BIG TECH data scraping and CORPORATE EXPLOITATION, prioritizing PUBLIC INTEREST.
# snippets_1    [ Tote california Privay Protection gency,\npleased tached the comments CTIAn pons othe gene Note of Madeatons to Proposed Parlin repeengCoaupdne, joes non and auarce eins,  These rule should elec the needs of everyday peopo to be protected fom <...
# Name: 147, dtype: object

# %% [markdown]
# # Calculate cluster co-occurrence in a document

# %%
import clustering_utils as c
reload(c)
# Out:
# <module 'clustering_utils' from '/Users/spangher/Projects/stanford-research/rfi-research/regulations-demo/notebooks/clustering_utils.py'>

# %%
G = c.compute_cluster_cooccurrence_graph(
    argument_records,
    cluster_col="bgmm_cluster",   # or "bgmm_cluster" if you want GMM groupings
    doc_col="doc_id",
    min_weight=5.0,          # only keep edges with lift > 1
    weight_metric="lift",    # or "count" for raw co-occurrence
)

# %%
from networkx.algorithms.community import greedy_modularity_communities
communities = greedy_modularity_communities(G, weight="weight")

# %%
for i, c in enumerate(list(filter(lambda x: len(x) > 2, communities))):
    print(f'==============Community {i+1}==============')
    print()
    for c_i in c:
        print('  * ' + cluster_summary_concat.apply(lambda x: f"{x['keyword']}: {x['summary']}", axis=1).iloc[c_i - 1])
    print()
    print()
# Out:
# ==============Community 1==============
#
#   * Adaptive regulation: Mandate adaptive, iterative regulation—regular reviews/updates, formal mechanisms (including public input) to swiftly address evolving AI capabilities, risks, and uncertainty.
#   * Flexible governance: Advocate flexible, scalable, tailored federal AI governance—avoiding sectoral fragmentation, leveraging existing accreditation, adaptable CAIO roles, and learning-by-doing.
#   * Reject self-regulation: Rejects industry self-regulation, demanding mandatory enforceable laws and expert regulators to ensure accountability, curb profit-driven abuse, and protect copyright.
#   * Data access: Ensure government‑facilitated, secure/anonymized access to large, high‑quality, representative datasets and aligned IP/data policies (EU/UK/Open Science) to enable safe, competitive AI.
#   * Enforced remediation: Require strict enforcement—penalties and retroactive remedies (forced deletion/retraining, detection tools) for models trained on unauthorized/sensitive data, with ongoing liability.
#   * Ban/Moratorium: Call for bans/moratoria and strict regulation of commercial generative AI—prioritizing accountability, consent, compensation, disclosure, penalties, and dataset‑cleaning.
#   * Expert authority: Urges policymakers to consult AI experts and institutions (e.g., IEEE), relying on expert consensus to legitimize urgent, safety-focused regulation.
#   * Regulate automated decisions: Urge enforceable, consumer‑first rules restricting automated decision‑making and requiring human oversight to protect privacy, safety, informed consent, and resist industry influence.
#   * Waiver limits: Require narrow, time‑limited waivers with objective criteria, public reporting, independent oversight and review, appeal rights, and clear accountability/liability.
#   * Procedural fairness: Urges restarting/revising rushed rulemaking to ensure procedural fairness/due‑process, stakeholder input, defined enforcement procedures, uniform timelines, and multilingual access.
#   * AI procurement governance: Mandate AI-specific procurement reforms—pre-award testing, vendor transparency and accountability, equity-forward contracts, enforceable penalties, data-rights clarity, interoperability to avoid vendor lock‑in.
#   * Consumer rights: Mandate enforceable consumer rights—access, correction, deletion, opt‑out/opt‑in—with authorized agents, affirmative consent, low‑burden processes and anti‑retaliation protections.
#   * Underestimated costs: Stakeholders assert the SRIA underestimates costs and omits key impacts, demanding rigorous, transparent economic analysis and relief for small/minority‑owned firms.
#
#
# ==============Community 2==============
#
#   * Openness for security: Argues openness and transparency — enabling local/air‑gapped deployment, auditability, collaborative defense, and regulatory oversight — improves security, privacy, accountability, and reduces concentration.
#   * Security/fraud exemptions: Stakeholders seek narrowly tailored carve-outs/exemptions—security, fraud‑prevention, business‑sensitive data, infrastructure tools, and R&D/testing—to preserve protections and operational flexibility across industries.
#   * Technological inevitability: Argues AI's technological inevitability and ubiquity make strict regulation futile, risking innovation chill, industry/talent flight, and economic competitiveness loss.
#   * Youth protections: Require heightened protections for minors and vulnerable populations: age-based safeguards, sensitive-data rules, parental consent, and provider responsibility against AI harms.
#   * Federal funding oversight: Mandate federal oversight and funding conditions on all federally-related AI—including state/local and military—covering transparency, fairness, privacy, safety, and contextual harms.
#   * Multistakeholder standards: Calls for coordinated public–private, multistakeholder standards and governance (NIST, international bodies), consensus-driven processes, civil‑society inclusion, and safeguards against industry capture.
#   * California AI leadership: California should lead nationally by adopting strong, worker‑focused AI rules—privacy, transparency, licensing, audits, opt‑outs—to protect jobs, rights, and set precedent.
#   * EU harmonisation: Call for EU-wide harmonisation under a single-market framework to avoid fragmentation, ensure regulatory certainty, a level playing field, and competitiveness.
#   * Actionable evidence-based oversight: Advocate evidence‑based, decision‑maker‑centric AI governance: targeted oversight focused on endpoints, audience‑tailored actionable recommendations justified by empirical harms and poor compliance.
#   * AI sustainability: Require AI regulation to measure and mitigate environmental impacts—energy, carbon, water, materials, e‑waste—holding developers accountable with sustainability standards and incentives.
#
#
# ==============Community 3==============
#
#   * Regulatory duplication: Warns the proposal duplicates NAIC, NIST/ISO, and statutory frameworks prematurely, creating overlapping audits, inconsistent definitions, and unnecessary compliance burdens.
#   * Central coordination: Calls for a central coordinating body—independent regulator or hub—providing coordination, horizon‑scanning, registers, data‑sharing, and enforcement/statutory backing to avoid fragmented regulation.
#   * Deepfakes & Misinformation: AI-generated deepfakes threaten misinformation, political propaganda, impersonation, privacy (nonconsensual sexual images), and public-safety harms, eroding trust and requiring regulation.
#   * Privacy risks: AI training and deployment risk privacy and human-rights violations—surveillance, biometric/minors’ data exposure, memorization/overfitting, illegal/toxic training data, and breaches enabling unauthorized secondary uses.
#   * Clear definitions: Require clear, precise definitions of "AI" and related terms, ensuring technical accuracy, legal certainty, and predictable, enforceable obligations.
#   * Moral opposition: Ethical/moral objection: commercial AI art is seen as exploitative, disrespectful, devaluing artists' dignity and rights, demanding non‑exploitative alternatives and opt‑out.
#   * Regulatory sandboxes: Promote regulatory sandboxes and flexible, case-by-case, voluntary governance to foster SME‑accessible innovation, fair transparent access, and risk‑managed R&D.
#   * Human rights: Frames AI as a human-rights issue threatening housing, education, and employment—demanding anti-discrimination protections, accountability, and limits on data scraping.
#
#
# ==============Community 4==============
#
#   * Labor protections: Require labor protections for moderators, annotators, crowdworkers (including volunteers), with mental‑health safeguards, fair pay, supply‑chain accountability, safe working conditions.
#   * Regulated adoption: Conditional support for generative AI: endorse ETHICAL, REGULATED, RISK‑MANAGED adoption with LEGAL GUARDRAILS, HUMAN OVERSIGHT, TESTING/MONITORING, citing historical analogies (weapons/crypto).
#   * Sociotechnical governance: AI governance must adopt a socio-technical, system-of-systems approach—covering organizational, supply‑chain, third‑party, lifecycle, participatory accountability and contextual impacts.
#   * Supportive regulation: Generally supportive of proactive, balanced AI regulation—favoring consumer protection, industry‑feasible, pro‑innovation rules, widespread NIST RMF adoption, and EU leadership.
#   * Provenance labeling: Mandate durable, tamper‑resistant provenance labels/watermarks and transparent training/model disclosure to protect consumers, prevent deception, spoofing, and unauthorized monetization.
#   * Regulatory scope: Favor an EU values-based mandatory AI law delegating sectoral premarket oversight and GDPR adaptations to regulators, complemented by non-binding ethical guidance.
#
#
# ==============Community 5==============
#
#   * Transparency fatigue: Extensive notices/opt-outs and explainability mandates risk NOTICE FATIGUE, degraded UX, infeasibility, privacy/security harms, and ACCURACY tradeoffs; opaque models raise trust concerns.
#   * Personal harm testimony: Personal testimonies and evidence of harms argue LLMs—lacking human nuance, empathy, and verifiable reasoning—should be barred from high‑risk decisions.
#   * Workforce & Resourcing: Require RESKILLING and PROFESSIONAL COMPETENCY; fund regulatory CAPACITY (multidisciplinary teams, monitoring, clear roles) and sustained BUDGETS for AI governance.
#
#
# ==============Community 6==============
#
#   * Pro-innovation: PRO‑INNOVATION: governments should aggressively adopt AI to foster economic growth, startup innovation, productivity, and societal benefits without stifling regulation.
#   * Regulation ineffective: Regulation is ineffective, unenforceable: bans and technical restrictions are easily circumvented, cause leakage, drive development abroad/underground, burden compliant actors.
#   * Risk-proportionality: Adopt a risk‑based, proportional regulatory approach: scale obligations to system risk, context, and resources—lighter for low‑risk, stricter for high‑risk.

# %%
distinct_responses = list(set(responses))
show_text_diff(distinct_responses[0], distinct_responses[1])
show_text_diff(distinct_responses[1], distinct_responses[2])
show_text_diff(distinct_responses[0], distinct_responses[2])
# Out:
#     <table style="border-collapse:collapse;width:100%;">
#       <tr>
#         <th style="text-align:left;padding:6px;border-bottom:1px solid #ccc;">Text A</th>
#         <th style="text-align:left;padding:6px;border-bottom:1px solid #ccc;">Text B</th>
#       </tr>
#       <tr>
#         <td style="vertical-align:top;padding:8px;font-family:monospace;white-space:pre-
# wrap;">Feedback from: gauthier lasou
#
# A European regulation that will set out ethical and legal requirements for AI usage in Europe.
# written in English, 108 pages + annexes, impact studies, etc.
# To my knowledge, you are addressing European citizens who do not all understand English, especially when a specific jargon is used to define common rules.
# For my part, although I read English, I am against this regulation only because it was not written in a language which I have sufficient knowledge to make.
# by publishing these documents in only one language, which is no longer a reference to one of the EU countries, you create a de facto inequality in the treatment, understanding and acceptance of the rules you want to set.</td>
#         <td style="vertical-align:top;padding:8px;font-family:monospace;white-space:pre-
# wrap;">Feedback from: gauthier lasou
#
# A European regulation that will set out ethical and legal requirements for AI usage in Europe.<span style="background:#d6ffd6;">
# </span>
# written in English, 108 pages + annexes, impact studies, etc.
# <span style="background:#d6ffd6;">
# </span>To my knowledge, you are addressing European citizens who do not all understand English, especially when a specific jargon is used to define common rules.
# <span style="background:#d6ffd6;">
# </span>For my part, although I read English, I am against this regulation only because it was not written in a language which I have sufficient knowledge to make.<span style="background:#d6ffd6;">
# </span>
# by publishing these documents in only one language, which is no longer a reference to one of the EU countries, you create a de facto inequality in the treatment, understanding and acceptance of the rules you want to set.</td>
#       </tr>
#     </table>
#     <table style="border-collapse:collapse;width:100%;">
#       <tr>
#         <th style="text-align:left;padding:6px;border-bottom:1px solid #ccc;">Text A</th>
#         <th style="text-align:left;padding:6px;border-bottom:1px solid #ccc;">Text B</th>
#       </tr>
#       <tr>
#         <td style="vertical-align:top;padding:8px;font-family:monospace;white-space:pre-
# wrap;">Feedback from: gauthier lasou
#
# A European regulation that will set out ethical and legal requirements for AI usage in Europe.<span style="background:#ffe5b4;">
#
# </span>written in English, 108 pages + annexes, impact studies, etc.<span style="background:#ffe5b4;">
#
# </span>To my knowledge, you are addressing European citizens who do not all understand English, especially when a specific jargon is used to define common rules.<span style="background:#ffe5b4;">
#
# </span>For my part, although I read English, I am against this regulation only because it was not written in a language which I have sufficient knowledge to make.<span style="background:#ffe5b4;">
#
# </span>by publishing these documents in only one language, which is no longer a reference to one of the EU countries, you create a de facto inequality in the treatment, understanding and acceptance of the rules you want to set.</td>
#         <td style="vertical-align:top;padding:8px;font-family:monospace;white-space:pre-
# wrap;">Feedback from: gauthier lasou
#
# A European regulation that will set out ethical and legal requirements for AI usage in Europe.<span style="background:#ffe5b4;"> </span>written in English, 108 pages + annexes, impact studies, etc.<span style="background:#ffe5b4;"> </span>To my knowledge, you are addressing European citizens who do not all understand English, especially when a specific jargon is used to define common rules.<span style="background:#ffe5b4;"> </span>For my part, although I read English, I am against this regulation only because it was not written in a language which I have sufficient knowledge to make.<span style="background:#ffe5b4;"> </span>by publishing these documents in only one language, which is no longer a reference to one of the EU countries, you create a de facto inequality in the treatment, understanding and acceptance of the rules you want to set.</td>
#       </tr>
#     </table>
#     <table style="border-collapse:collapse;width:100%;">
#       <tr>
#         <th style="text-align:left;padding:6px;border-bottom:1px solid #ccc;">Text A</th>
#         <th style="text-align:left;padding:6px;border-bottom:1px solid #ccc;">Text B</th>
#       </tr>
#       <tr>
#         <td style="vertical-align:top;padding:8px;font-family:monospace;white-space:pre-
# wrap;">Feedback from: gauthier lasou
#
# A European regulation that will set out ethical and legal requirements for AI usage in Europe.<span style="background:#ffe5b4;">
# </span>written in English, 108 pages + annexes, impact studies, etc.<span style="background:#ffe5b4;">
# </span>To my knowledge, you are addressing European citizens who do not all understand English, especially when a specific jargon is used to define common rules.<span style="background:#ffe5b4;">
# </span>For my part, although I read English, I am against this regulation only because it was not written in a language which I have sufficient knowledge to make.<span style="background:#ffe5b4;">
# </span>by publishing these documents in only one language, which is no longer a reference to one of the EU countries, you create a de facto inequality in the treatment, understanding and acceptance of the rules you want to set.</td>
#         <td style="vertical-align:top;padding:8px;font-family:monospace;white-space:pre-
# wrap;">Feedback from: gauthier lasou
#
# A European regulation that will set out ethical and legal requirements for AI usage in Europe.<span style="background:#ffe5b4;"> </span>written in English, 108 pages + annexes, impact studies, etc.<span style="background:#ffe5b4;"> </span>To my knowledge, you are addressing European citizens who do not all understand English, especially when a specific jargon is used to define common rules.<span style="background:#ffe5b4;"> </span>For my part, although I read English, I am against this regulation only because it was not written in a language which I have sufficient knowledge to make.<span style="background:#ffe5b4;"> </span>by publishing these documents in only one language, which is no longer a reference to one of the EU countries, you create a de facto inequality in the treatment, understanding and acceptance of the rules you want to set.</td>
#       </tr>
#     </table>

# %% [markdown]
# ## 8. Next Steps
#
# - Investigate rows with `missing_text` to determine if extraction retries are needed.
# - Add derived reporting tables to `data/app_data/ai_corpus.db` for timelines or organization rollups.
# - When importing new connectors, keep their assets under `data/comments/<connector>/` so the overview table picks them up automatically.
